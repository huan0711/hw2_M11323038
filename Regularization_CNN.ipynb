# %%
import numpy as np 
import os
import tensorflow  as tf
from keras.models import Sequential
from keras.layers import Dense,Conv2D,Flatten,MaxPooling2D,UpSampling2D,InputLayer,Reshape

from keras.utils import image_dataset_from_directory
from keras.layers import Dropout,Activation,BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array
from tensorflow.keras.utils import array_to_img
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt

from keras.layers import LeakyReLU
from pathlib import Path
from skimage.io import imread
from skimage.transform import resize
from sklearn.utils import Bunch
import math
import pandas as pd
import datetime
import time
import csv
import numpy as np
from glob import glob

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import time
import datetime
import os
from PIL import Image
import sys

# %%
# 設定圖片大小和路徑
img_rows, img_cols = 256,256  # 縮小圖片尺寸以減少記憶體使用
train_data_dir = "D:/桌面/ML/temp/data/train"
test_data_dir = "D:/桌面/ML/temp/data/test"
output_dir = 'D:/桌面/ML/temp/MLWORK/regularization'

# %%
# 準備測試不同的參數
epochs_list = [20, 40, 60]
batch_size_list = [8, 16]

# %%
# 對每種參數組合進行實驗
results = {}  # 用來存儲所有結果的字典

csv_filename = 'regularization_training_results.csv'
detailed_csv_filename = os.path.join(output_dir, 'regularization_detailed_training_results.csv')
summary_csv_filename = os.path.join(output_dir, 'regularization_summary_results.csv')
plot_filename = os.path.join(output_dir, 'regularization_training_comparison.png')

os.makedirs(output_dir, exist_ok=True)

# 創建基本CSV文件並寫入標題
fieldnames = ['epochs', 'batch_size', 'train_acc', 'val_acc', 'test_acc', 
              'train_loss', 'val_loss', 'test_loss', 'training_time', 
              'overall_accuracy', 'men_accuracy', 'women_accuracy']

# 創建基本結果CSV
with open(csv_filename, 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()

# 創建詳細結果CSV (每個epoch的數據)
detailed_fieldnames = ['combination', 'epoch', 'train_acc', 'val_acc', 'test_acc', 'train_loss', 'val_loss', 'test_loss']
with open(detailed_csv_filename, 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=detailed_fieldnames)
    writer.writeheader()

# %%
# 這邊只是輸出模型架構不然後面寫在迴圈裡會輸出很多次
reference_model = Sequential()

reference_model.add(Conv2D(32, (3,3), padding="same", input_shape=(img_rows,img_cols,3)))
reference_model.add(Activation("relu"))
reference_model.add(MaxPooling2D(pool_size=(3,3)))

reference_model.add(Conv2D(64, (3,3), padding="same"))
reference_model.add(Activation("relu"))

reference_model.add(Conv2D(64, (3,3), padding="same"))
reference_model.add(Activation("relu"))
reference_model.add(MaxPooling2D(pool_size=(2,2)))


reference_model.add(Conv2D(128, (3,3), padding="same"))
reference_model.add(Activation("relu"))


reference_model.add(Conv2D(128, (3,3), padding="same"))
reference_model.add(Activation("relu"))
reference_model.add(MaxPooling2D(pool_size=(2,2)))
reference_model.add(Dropout(0.2))                     # 新增 Dropout

reference_model.add(Flatten())
reference_model.add(Dense(1024, activation='relu'))
reference_model.add(Dropout(0.5))                     # 新增 Dropout
reference_model.add(Dense(1, activation='sigmoid'))



# 只顯示一次模型摘要
print("\n模型架構 (含 Dropout)::")
reference_model.summary()
# Out:
# 模型架構 (含 Dropout)::
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 32)      896
#
#  activation (Activation)     (None, 256, 256, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 85, 85, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 85, 85, 64)        18496
#
#  activation_1 (Activation)   (None, 85, 85, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 85, 85, 64)        36928
#
#  activation_2 (Activation)   (None, 85, 85, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 42, 42, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 42, 42, 128)       73856
#
#  activation_3 (Activation)   (None, 42, 42, 128)       0
#
#  conv2d_4 (Conv2D)           (None, 42, 42, 128)       147584
#
#  activation_4 (Activation)   (None, 42, 42, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 21, 21, 128)      0
#  2D)
#
#  dropout (Dropout)           (None, 21, 21, 128)       0
#
#  flatten (Flatten)           (None, 56448)             0
#
#  dense (Dense)               (None, 1024)              57803776
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 58,082,561
# Trainable params: 58,082,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
for epochs in epochs_list:
    for batch_size in batch_size_list:
        print(f"\n開始訓練 - epochs: {epochs}, batch_size: {batch_size}")

        # validation set切分設定為 0.2
        train_datagen = ImageDataGenerator(
            validation_split=0.2,
            rescale=1./255,         
            rotation_range=10,       # 旋轉圖像15度
            # width_shift_range=0.1,   # 水平平移圖像總寬度的 10%
            # height_shift_range=0.1,  # 垂直平移圖像總高度的 10%
            # shear_range=0.1,         # 應用剪切變換
            zoom_range=0.1,          # 縮放圖像
            horizontal_flip=True,    # 水平翻轉圖像
            # fill_mode='nearest'      # 填充新創建像素的方法
        )
        
        validation_datagen = ImageDataGenerator(
            validation_split=0.2,
            rescale=1./255
        )
        
        test_datagen = ImageDataGenerator(rescale=1./255)
        
        train_generator = train_datagen.flow_from_directory(
            train_data_dir,
            target_size=(img_rows, img_cols),
            batch_size=batch_size,
            class_mode='binary',
            shuffle=True,
            subset='training'
        )
        
        validation_generator = validation_datagen.flow_from_directory(
            train_data_dir,
            target_size=(img_rows, img_cols),
            batch_size=batch_size,
            class_mode='binary',
            shuffle=False,
            subset='validation'
        )
        
        test_generator = test_datagen.flow_from_directory(
            test_data_dir,
            target_size=(img_rows, img_cols),
            batch_size=batch_size,
            class_mode='binary',
            shuffle=False
        )
        
        model = Sequential()
        model.add(Conv2D(32, (3,3), padding="same", input_shape=(img_rows,img_cols,3)))
        model.add(Activation("relu"))
        model.add(MaxPooling2D(pool_size=(3,3)))
        model.add(Conv2D(64, (3,3), padding="same"))
        model.add(Activation("relu"))
        model.add(Conv2D(64, (3,3), padding="same"))
        model.add(Activation("relu"))
        model.add(MaxPooling2D(pool_size=(2,2)))
        model.add(Conv2D(128, (3,3), padding="same"))
        model.add(Activation("relu"))
        model.add(Conv2D(128, (3,3), padding="same"))
        model.add(Activation("relu"))
        model.add(MaxPooling2D(pool_size=(2,2)))
        model.add(Dropout(0.2))
        model.add(Flatten())
        model.add(Dense(1024, activation='relu'))
        model.add(Dropout(0.5))
        model.add(Dense(1, activation='sigmoid'))
        
        model.compile(
            loss='binary_crossentropy',
            optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
            metrics=['accuracy']
        )
        
        start_time = time.time()
        
        # 自訂回調函數，在每個 epoch 結束後計算 test_acc 和 test_loss
        test_acc_history = []
        test_loss_history = []
        
        class TestCallback(tf.keras.callbacks.Callback):
            def on_epoch_end(self, epoch, logs=None):
                test_loss, test_acc = model.evaluate(
                    test_generator,
                    steps=test_generator.samples // batch_size + 1,
                    verbose=0
                )
                test_acc_history.append(test_acc)
                test_loss_history.append(test_loss)
                print(f"Epoch {epoch + 1}: Test Accuracy = {test_acc:.4f}, Test Loss = {test_loss:.4f}")
        
        # 訓練模型，並在每個 epoch 結束後計算 test_acc 和 test_loss
        history = model.fit(
            train_generator,
            steps_per_epoch=train_generator.samples // batch_size,
            epochs=epochs,
            validation_data=validation_generator,
            validation_steps=validation_generator.samples // batch_size if validation_generator.samples // batch_size > 0 else 1,
            callbacks=[TestCallback()]
        )
        
        end_time = time.time()
        training_time = end_time - start_time
        formatted_time = str(datetime.timedelta(seconds=int(training_time)))
        
        # 在測試集上評估模型（最終結果）
        test_loss, test_acc = model.evaluate(
            test_generator,
            steps=test_generator.samples // batch_size + 1
        )
        
        y_pred = model.predict(test_generator, steps=test_generator.samples // batch_size + 1)
        y_pred_classes = (y_pred > 0.5).astype(int).flatten()
        
        test_generator.reset()
        y_true = test_generator.classes
        
        overall_accuracy = np.mean(y_pred_classes == y_true)
        
        class_accuracies = {}
        for class_idx, class_name in enumerate(test_generator.class_indices.keys()):
            class_samples = np.where(y_true == class_idx)[0]
            if len(class_samples) > 0:
                class_correct = np.sum(y_pred_classes[class_samples] == class_idx)
                class_accuracy = class_correct / len(class_samples)
                class_accuracies[class_name] = class_accuracy
            else:
                class_accuracies[class_name] = 0.0
        
        final_train_acc = history.history['accuracy'][-1]
        final_train_loss = history.history['loss'][-1]
        final_val_acc = history.history['val_accuracy'][-1] if 'val_accuracy' in history.history else None
        final_val_loss = history.history['val_loss'][-1] if 'val_loss' in history.history else None
        
        key = f"epochs_{epochs}_batch_{batch_size}"
        results[key] = {
            'history': history.history,
            'test_acc': test_acc,
            'test_loss': test_loss,
            'test_acc_history': test_acc_history,
            'test_loss_history': test_loss_history,
            'training_time': training_time,
            'formatted_time': formatted_time,
            'overall_accuracy': overall_accuracy,
            'class_accuracies': class_accuracies,
            'train_acc': final_train_acc,
            'train_loss': final_train_loss,
            'val_acc': final_val_acc,
            'val_loss': final_val_loss
        }
        
        # 輸出結果
        print(f"\n訓練完成 - epochs: {epochs}, batch_size: {batch_size}")
        print(f"訓練集準確率: {final_train_acc:.4f}, 損失: {final_train_loss:.4f}")
        print(f"驗證集準確率: {final_val_acc:.4f}, 損失: {final_val_loss:.4f}")
        print(f"測試集準確率: {test_acc:.4f}, 損失: {test_loss:.4f}")
        print(f"整體準確率(不分性別): {overall_accuracy:.4f}")
        print(f"訓練時間: {formatted_time}")
        print("各類別準確率:")
        for class_name, accuracy in class_accuracies.items():
            print(f"  {class_name}: {accuracy:.4f}")
            
        # 將結果寫入CSV
        with open(csv_filename, 'a', newline='') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            writer.writerow({
                'epochs': epochs,
                'batch_size': batch_size,
                'train_acc': f"{final_train_acc:.4f}",
                'val_acc': f"{final_val_acc:.4f}" if final_val_acc is not None else None,
                'test_acc': f"{test_acc:.4f}",
                'train_loss': f"{final_train_loss:.4f}",
                'val_loss': f"{final_val_loss:.4f}" if final_val_loss is not None else None,
                'test_loss': f"{test_loss:.4f}",
                'training_time': formatted_time,
                'overall_accuracy': f"{overall_accuracy:.4f}",
                'men_accuracy': f"{class_accuracies.get('men', 0.0):.4f}",
                'women_accuracy': f"{class_accuracies.get('women', 0.0):.4f}"
            })
            
        # 保存每個 epoch 的詳細資訊（包含 test_acc 和 test_loss）
        with open(detailed_csv_filename, 'a', newline='') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=detailed_fieldnames)
            for i in range(len(history.history['accuracy'])):
                writer.writerow({
                    'combination': key,
                    'epoch': i+1,
                    'train_acc': f"{history.history['accuracy'][i]:.4f}",
                    'val_acc': f"{history.history['val_accuracy'][i]:.4f}" if 'val_accuracy' in history.history else None,
                    'test_acc': f"{test_acc_history[i]:.4f}",
                    'train_loss': f"{history.history['loss'][i]:.4f}",
                    'val_loss': f"{history.history['val_loss'][i]:.4f}" if 'val_loss' in history.history else None,
                    'test_loss': f"{test_loss_history[i]:.4f}"
                })
# Out:
# 開始訓練 - epochs: 20, batch_size: 8
# Found 176 images belonging to 2 classes.
# Found 44 images belonging to 2 classes.
# Found 80 images belonging to 2 classes.
# Epoch 1/20
# 22/22 [==============================] - ETA: 0s - loss: 1.1513 - accuracy: 0.4545WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 1: Test Accuracy = 0.5000, Test Loss = 0.6930
# 22/22 [==============================] - 17s 630ms/step - loss: 1.1513 - accuracy: 0.4545 - val_loss: 0.6927 - val_accuracy: 0.5500
# Epoch 2/20
# 22/22 [==============================] - ETA: 0s - loss: 0.6942 - accuracy: 0.3750WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 2: Test Accuracy = 0.5000, Test Loss = 0.6931
# 22/22 [==============================] - 12s 547ms/step - loss: 0.6942 - accuracy: 0.3750 - val_loss: 0.6930 - val_accuracy: 0.5500
# Epoch 3/20
# 22/22 [==============================] - ETA: 0s - loss: 0.6944 - accuracy: 0.4773WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 3: Test Accuracy = 0.6000, Test Loss = 0.6931
# 22/22 [==============================] - 12s 568ms/step - loss: 0.6944 - accuracy: 0.4773 - val_loss: 0.6931 - val_accuracy: 0.4750
# Epoch 4/20
# 22/22 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5455WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 4: Test Accuracy = 0.5000, Test Loss = 0.6931
# 22/22 [==============================] - 12s 556ms/step - loss: 0.6933 - accuracy: 0.5455 - val_loss: 0.6928 - val_accuracy: 0.5500
# Epoch 5/20
# 22/22 [==============================] - ETA: 0s - loss: 0.6942 - accuracy: 0.4432WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 5: Test Accuracy = 0.5000, Test Loss = 0.6931
# 22/22 [==============================] - 13s 577ms/step - loss: 0.6942 - accuracy: 0.4432 - val_loss: 0.6937 - val_accuracy: 0.4500
# Epoch 6/20
# 22/22 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4943WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 6: Test Accuracy = 0.5000, Test Loss = 0.6932
# 22/22 [==============================] - 12s 546ms/step - loss: 0.6932 - accuracy: 0.4943 - val_loss: 0.6935 - val_accuracy: 0.4500
# Epoch 7/20
# 22/22 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.4489WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 7: Test Accuracy = 0.5000, Test Loss = 0.6932
# 22/22 [==============================] - 12s 555ms/step - loss: 0.6934 - accuracy: 0.4489 - val_loss: 0.6935 - val_accuracy: 0.4500
# Epoch 8/20
# 22/22 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.4830WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 8: Test Accuracy = 0.5000, Test Loss = 0.6931
# 22/22 [==============================] - 12s 563ms/step - loss: 0.6931 - accuracy: 0.4830 - val_loss: 0.6933 - val_accuracy: 0.4500
# Epoch 9/20
# 22/22 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5398WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 9: Test Accuracy = 0.5000, Test Loss = 0.6931
# 22/22 [==============================] - 12s 552ms/step - loss: 0.6931 - accuracy: 0.5398 - val_loss: 0.6931 - val_accuracy: 0.5500
# Epoch 10/20
# 22/22 [==============================] - ETA: 0s - loss: 0.6938 - accuracy: 0.4716WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 10: Test Accuracy = 0.5000, Test Loss = 0.6932
# 22/22 [==============================] - 12s 543ms/step - loss: 0.6938 - accuracy: 0.4716 - val_loss: 0.6936 - val_accuracy: 0.4500
# Epoch 11/20
# 22/22 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.4602WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 11: Test Accuracy = 0.5000, Test Loss = 0.6931
# 22/22 [==============================] - 12s 549ms/step - loss: 0.6936 - accuracy: 0.4602 - val_loss: 0.6933 - val_accuracy: 0.4500
# Epoch 12/20
# 22/22 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5511WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 12: Test Accuracy = 0.5000, Test Loss = 0.6931
# 22/22 [==============================] - 12s 557ms/step - loss: 0.6929 - accuracy: 0.5511 - val_loss: 0.6933 - val_accuracy: 0.4500
# Epoch 13/20
# 22/22 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.5114WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 13: Test Accuracy = 0.5000, Test Loss = 0.6931
# 22/22 [==============================] - 12s 553ms/step - loss: 0.6934 - accuracy: 0.5114 - val_loss: 0.6930 - val_accuracy: 0.5500
# Epoch 14/20
# 22/22 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5057WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 14: Test Accuracy = 0.5000, Test Loss = 0.6931
# 22/22 [==============================] - 12s 545ms/step - loss: 0.6931 - accuracy: 0.5057 - val_loss: 0.6933 - val_accuracy: 0.4500
# Epoch 15/20
# 22/22 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.4716WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 15: Test Accuracy = 0.5000, Test Loss = 0.6931
# 22/22 [==============================] - 12s 546ms/step - loss: 0.6934 - accuracy: 0.4716 - val_loss: 0.6930 - val_accuracy: 0.5500
# Epoch 16/20
# 22/22 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.4886WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 16: Test Accuracy = 0.5000, Test Loss = 0.6931
# 22/22 [==============================] - 12s 547ms/step - loss: 0.6930 - accuracy: 0.4886 - val_loss: 0.6931 - val_accuracy: 0.5500
# Epoch 17/20
# 22/22 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.4716WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 17: Test Accuracy = 0.5000, Test Loss = 0.6931
# 22/22 [==============================] - 12s 549ms/step - loss: 0.6934 - accuracy: 0.4716 - val_loss: 0.6930 - val_accuracy: 0.5500
# Epoch 18/20
# 22/22 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5057WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 18: Test Accuracy = 0.5000, Test Loss = 0.6931
# 22/22 [==============================] - 12s 550ms/step - loss: 0.6933 - accuracy: 0.5057 - val_loss: 0.6931 - val_accuracy: 0.5500
# Epoch 19/20
# 22/22 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.4375WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 19: Test Accuracy = 0.5000, Test Loss = 0.6931
# 22/22 [==============================] - 12s 543ms/step - loss: 0.6934 - accuracy: 0.4375 - val_loss: 0.6931 - val_accuracy: 0.5500
# Epoch 20/20
# 22/22 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5398WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 20: Test Accuracy = 0.5000, Test Loss = 0.6931
# 22/22 [==============================] - 12s 552ms/step - loss: 0.6931 - accuracy: 0.5398 - val_loss: 0.6931 - val_accuracy: 0.5500
# 10/11 [==========================>...] - ETA: 0s - loss: 0.6931 - accuracy: 0.5000WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# 11/11 [==============================] - 3s 285ms/step - loss: 0.6931 - accuracy: 0.5000
# 10/11 [==========================>...] - ETA: 0sWARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# 11/11 [==============================] - 3s 289ms/step
#
# 訓練完成 - epochs: 20, batch_size: 8
# 訓練集準確率: 0.5398, 損失: 0.6931
# 驗證集準確率: 0.5500, 損失: 0.6931
# 測試集準確率: 0.5000, 損失: 0.6931
# 整體準確率(不分性別): 0.5000
# 訓練時間: 0:04:09
# 各類別準確率:
#   men: 1.0000
#   women: 0.0000
#
# 開始訓練 - epochs: 20, batch_size: 16
# Found 176 images belonging to 2 classes.
# Found 44 images belonging to 2 classes.
# Found 80 images belonging to 2 classes.
# Epoch 1/20
# 11/11 [==============================] - ETA: 0s - loss: 0.8060 - accuracy: 0.4773WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 1: Test Accuracy = 0.5000, Test Loss = 0.6931
# 11/11 [==============================] - 14s 1s/step - loss: 0.8060 - accuracy: 0.4773 - val_loss: 0.6951 - val_accuracy: 0.3125
# Epoch 2/20
# 11/11 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.4773WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 2: Test Accuracy = 0.5000, Test Loss = 0.6931
# 11/11 [==============================] - 12s 1s/step - loss: 0.6933 - accuracy: 0.4773 - val_loss: 0.6943 - val_accuracy: 0.3125
# Epoch 3/20
# 11/11 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.5057WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 3: Test Accuracy = 0.5000, Test Loss = 0.6931
# 11/11 [==============================] - 12s 1s/step - loss: 0.6936 - accuracy: 0.5057 - val_loss: 0.6955 - val_accuracy: 0.3125
# Epoch 4/20
# 11/11 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5000WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 4: Test Accuracy = 0.5000, Test Loss = 0.6931
# 11/11 [==============================] - 12s 1s/step - loss: 0.6929 - accuracy: 0.5000 - val_loss: 0.6938 - val_accuracy: 0.3125
# Epoch 5/20
# 11/11 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5284WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 5: Test Accuracy = 0.5000, Test Loss = 0.6931
# 11/11 [==============================] - 12s 1s/step - loss: 0.6931 - accuracy: 0.5284 - val_loss: 0.6936 - val_accuracy: 0.3125
# Epoch 6/20
# 11/11 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5000WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 6: Test Accuracy = 0.5000, Test Loss = 0.6931
# 11/11 [==============================] - 13s 1s/step - loss: 0.6933 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.3125
# Epoch 7/20
# 11/11 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5341WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 7: Test Accuracy = 0.5000, Test Loss = 0.6931
# 11/11 [==============================] - 13s 1s/step - loss: 0.6929 - accuracy: 0.5341 - val_loss: 0.6930 - val_accuracy: 0.6875
# Epoch 8/20
# 11/11 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5568WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 8: Test Accuracy = 0.5000, Test Loss = 0.6931
# 11/11 [==============================] - 13s 1s/step - loss: 0.6930 - accuracy: 0.5568 - val_loss: 0.6928 - val_accuracy: 0.6875
# Epoch 9/20
# 11/11 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5000WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 9: Test Accuracy = 0.5000, Test Loss = 0.6931
# 11/11 [==============================] - 13s 1s/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6928 - val_accuracy: 0.6875
# Epoch 10/20
# 11/11 [==============================] - ETA: 0s - loss: 0.6937 - accuracy: 0.4375WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 10: Test Accuracy = 0.5000, Test Loss = 0.6931
# 11/11 [==============================] - 13s 1s/step - loss: 0.6937 - accuracy: 0.4375 - val_loss: 0.6922 - val_accuracy: 0.6875
# Epoch 11/20
# 11/11 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5114WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 11: Test Accuracy = 0.5000, Test Loss = 0.6931
# 11/11 [==============================] - 13s 1s/step - loss: 0.6930 - accuracy: 0.5114 - val_loss: 0.6932 - val_accuracy: 0.3125
# Epoch 12/20
# 11/11 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5455WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 12: Test Accuracy = 0.5000, Test Loss = 0.6931
# 11/11 [==============================] - 12s 1s/step - loss: 0.6930 - accuracy: 0.5455 - val_loss: 0.6929 - val_accuracy: 0.6875
# Epoch 13/20
# 11/11 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4659WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 13: Test Accuracy = 0.5000, Test Loss = 0.6931
# 11/11 [==============================] - 13s 1s/step - loss: 0.6932 - accuracy: 0.4659 - val_loss: 0.6932 - val_accuracy: 0.3125
# Epoch 14/20
# 11/11 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4943WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 14: Test Accuracy = 0.5000, Test Loss = 0.6931
# 11/11 [==============================] - 12s 1s/step - loss: 0.6932 - accuracy: 0.4943 - val_loss: 0.6933 - val_accuracy: 0.3125
# Epoch 15/20
# 11/11 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.4602WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 15: Test Accuracy = 0.5250, Test Loss = 0.6931
# 11/11 [==============================] - 12s 1s/step - loss: 0.6933 - accuracy: 0.4602 - val_loss: 0.6931 - val_accuracy: 0.6875
# Epoch 16/20
# 11/11 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.4659WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 16: Test Accuracy = 0.5000, Test Loss = 0.6931
# 11/11 [==============================] - 12s 1s/step - loss: 0.6935 - accuracy: 0.4659 - val_loss: 0.6929 - val_accuracy: 0.6875
# Epoch 17/20
# 11/11 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.4602WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 17: Test Accuracy = 0.5000, Test Loss = 0.6931
# 11/11 [==============================] - 13s 1s/step - loss: 0.6936 - accuracy: 0.4602 - val_loss: 0.6925 - val_accuracy: 0.6875
# Epoch 18/20
# 11/11 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5114WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 18: Test Accuracy = 0.5000, Test Loss = 0.6931
# 11/11 [==============================] - 14s 1s/step - loss: 0.6930 - accuracy: 0.5114 - val_loss: 0.6924 - val_accuracy: 0.6875
# Epoch 19/20
# 11/11 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5227WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 19: Test Accuracy = 0.5000, Test Loss = 0.6931
# 11/11 [==============================] - 13s 1s/step - loss: 0.6932 - accuracy: 0.5227 - val_loss: 0.6929 - val_accuracy: 0.6875
# Epoch 20/20
# 11/11 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.4773WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 20: Test Accuracy = 0.5000, Test Loss = 0.6931
# 11/11 [==============================] - 12s 1s/step - loss: 0.6936 - accuracy: 0.4773 - val_loss: 0.6922 - val_accuracy: 0.6875
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6931 - accuracy: 0.5000WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# 6/6 [==============================] - 3s 507ms/step - loss: 0.6931 - accuracy: 0.5000
# 5/6 [========================>.....] - ETA: 0sWARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# 6/6 [==============================] - 3s 525ms/step
#
# 訓練完成 - epochs: 20, batch_size: 16
# 訓練集準確率: 0.4773, 損失: 0.6936
# 驗證集準確率: 0.6875, 損失: 0.6922
# 測試集準確率: 0.5000, 損失: 0.6931
# 整體準確率(不分性別): 0.5000
# 訓練時間: 0:04:14
# 各類別準確率:
#   men: 1.0000
#   women: 0.0000
#
# 開始訓練 - epochs: 40, batch_size: 8
# Found 176 images belonging to 2 classes.
# Found 44 images belonging to 2 classes.
# Found 80 images belonging to 2 classes.
# Epoch 1/40
# 22/22 [==============================] - ETA: 0s - loss: 1.0834 - accuracy: 0.4830WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 1: Test Accuracy = 0.5125, Test Loss = 0.6927
# 22/22 [==============================] - 13s 578ms/step - loss: 1.0834 - accuracy: 0.4830 - val_loss: 0.6932 - val_accuracy: 0.5250
# Epoch 2/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5057WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 2: Test Accuracy = 0.5000, Test Loss = 0.6932
# 22/22 [==============================] - 12s 560ms/step - loss: 0.6930 - accuracy: 0.5057 - val_loss: 0.6938 - val_accuracy: 0.4500
# Epoch 3/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5000WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 3: Test Accuracy = 0.5000, Test Loss = 0.6932
# 22/22 [==============================] - 12s 553ms/step - loss: 0.6930 - accuracy: 0.5000 - val_loss: 0.6940 - val_accuracy: 0.4500
# Epoch 4/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.5000WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 4: Test Accuracy = 0.5000, Test Loss = 0.6932
# 22/22 [==============================] - 12s 560ms/step - loss: 0.6936 - accuracy: 0.5000 - val_loss: 0.6937 - val_accuracy: 0.4500
# Epoch 5/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5057WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 5: Test Accuracy = 0.5000, Test Loss = 0.6932
# 22/22 [==============================] - 12s 547ms/step - loss: 0.6931 - accuracy: 0.5057 - val_loss: 0.6937 - val_accuracy: 0.4500
# Epoch 6/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5000WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 6: Test Accuracy = 0.5000, Test Loss = 0.6932
# 22/22 [==============================] - 12s 564ms/step - loss: 0.6933 - accuracy: 0.5000 - val_loss: 0.6939 - val_accuracy: 0.4500
# Epoch 7/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5000WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 7: Test Accuracy = 0.5000, Test Loss = 0.6932
# 22/22 [==============================] - 12s 564ms/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6938 - val_accuracy: 0.4500
# Epoch 8/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.5000WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 8: Test Accuracy = 0.5000, Test Loss = 0.6932
# 22/22 [==============================] - 12s 549ms/step - loss: 0.6936 - accuracy: 0.5000 - val_loss: 0.6935 - val_accuracy: 0.4500
# Epoch 9/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5170WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 9: Test Accuracy = 0.5000, Test Loss = 0.6932
# 22/22 [==============================] - 12s 576ms/step - loss: 0.6932 - accuracy: 0.5170 - val_loss: 0.6935 - val_accuracy: 0.4500
# Epoch 10/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.4943WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 10: Test Accuracy = 0.5000, Test Loss = 0.6932
# 22/22 [==============================] - 12s 562ms/step - loss: 0.6935 - accuracy: 0.4943 - val_loss: 0.6935 - val_accuracy: 0.4500
# Epoch 11/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.4659WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 11: Test Accuracy = 0.5000, Test Loss = 0.6932
# 22/22 [==============================] - 12s 567ms/step - loss: 0.6934 - accuracy: 0.4659 - val_loss: 0.6934 - val_accuracy: 0.4500
# Epoch 12/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.5909WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 12: Test Accuracy = 0.5000, Test Loss = 0.6931
# 22/22 [==============================] - 12s 563ms/step - loss: 0.6927 - accuracy: 0.5909 - val_loss: 0.6934 - val_accuracy: 0.4500
# Epoch 13/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5227WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 13: Test Accuracy = 0.5000, Test Loss = 0.6931
# 22/22 [==============================] - 12s 555ms/step - loss: 0.6929 - accuracy: 0.5227 - val_loss: 0.6934 - val_accuracy: 0.4500
# Epoch 14/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.5057WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 14: Test Accuracy = 0.5000, Test Loss = 0.6932
# 22/22 [==============================] - 12s 560ms/step - loss: 0.6934 - accuracy: 0.5057 - val_loss: 0.6936 - val_accuracy: 0.4500
# Epoch 15/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.5057WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 15: Test Accuracy = 0.5000, Test Loss = 0.6932
# 22/22 [==============================] - 12s 560ms/step - loss: 0.6936 - accuracy: 0.5057 - val_loss: 0.6936 - val_accuracy: 0.4500
# Epoch 16/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5455WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 16: Test Accuracy = 0.5000, Test Loss = 0.6931
# 22/22 [==============================] - 12s 555ms/step - loss: 0.6931 - accuracy: 0.5455 - val_loss: 0.6934 - val_accuracy: 0.4500
# Epoch 17/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5114WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 17: Test Accuracy = 0.5000, Test Loss = 0.6932
# 22/22 [==============================] - 12s 569ms/step - loss: 0.6933 - accuracy: 0.5114 - val_loss: 0.6934 - val_accuracy: 0.4500
# Epoch 18/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.4602WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 18: Test Accuracy = 0.5000, Test Loss = 0.6931
# 22/22 [==============================] - 12s 551ms/step - loss: 0.6933 - accuracy: 0.4602 - val_loss: 0.6933 - val_accuracy: 0.4500
# Epoch 19/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.5341WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 19: Test Accuracy = 0.5000, Test Loss = 0.6932
# 22/22 [==============================] - 12s 567ms/step - loss: 0.6928 - accuracy: 0.5341 - val_loss: 0.6935 - val_accuracy: 0.4500
# Epoch 20/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5000WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 20: Test Accuracy = 0.5000, Test Loss = 0.6931
# 22/22 [==============================] - 12s 558ms/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6934 - val_accuracy: 0.4500
# Epoch 21/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.4773WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 21: Test Accuracy = 0.5000, Test Loss = 0.6931
# 22/22 [==============================] - 12s 563ms/step - loss: 0.6929 - accuracy: 0.4773 - val_loss: 0.6933 - val_accuracy: 0.4500
# Epoch 22/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6938 - accuracy: 0.4489WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 22: Test Accuracy = 0.5000, Test Loss = 0.6931
# 22/22 [==============================] - 12s 561ms/step - loss: 0.6938 - accuracy: 0.4489 - val_loss: 0.6931 - val_accuracy: 0.5500
# Epoch 23/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.4943WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 23: Test Accuracy = 0.5000, Test Loss = 0.6931
# 22/22 [==============================] - 12s 554ms/step - loss: 0.6933 - accuracy: 0.4943 - val_loss: 0.6934 - val_accuracy: 0.4500
# Epoch 24/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.4545WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 24: Test Accuracy = 0.5000, Test Loss = 0.6931
# 22/22 [==============================] - 12s 565ms/step - loss: 0.6936 - accuracy: 0.4545 - val_loss: 0.6933 - val_accuracy: 0.4500
# Epoch 25/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.5398WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 25: Test Accuracy = 0.5000, Test Loss = 0.6931
# 22/22 [==============================] - 12s 564ms/step - loss: 0.6928 - accuracy: 0.5398 - val_loss: 0.6934 - val_accuracy: 0.4500
# Epoch 26/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.4886WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 26: Test Accuracy = 0.5000, Test Loss = 0.6931
# 22/22 [==============================] - 12s 544ms/step - loss: 0.6933 - accuracy: 0.4886 - val_loss: 0.6932 - val_accuracy: 0.4500
# Epoch 27/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6937 - accuracy: 0.4261WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 27: Test Accuracy = 0.5000, Test Loss = 0.6932
# 22/22 [==============================] - 12s 565ms/step - loss: 0.6937 - accuracy: 0.4261 - val_loss: 0.6936 - val_accuracy: 0.4500
# Epoch 28/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5398WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 28: Test Accuracy = 0.5000, Test Loss = 0.6931
# 22/22 [==============================] - 12s 564ms/step - loss: 0.6932 - accuracy: 0.5398 - val_loss: 0.6933 - val_accuracy: 0.4500
# Epoch 29/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.4375WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 29: Test Accuracy = 0.5000, Test Loss = 0.6931
# 22/22 [==============================] - 12s 565ms/step - loss: 0.6935 - accuracy: 0.4375 - val_loss: 0.6934 - val_accuracy: 0.4500
# Epoch 30/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.4773WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 30: Test Accuracy = 0.5000, Test Loss = 0.6932
# 22/22 [==============================] - 13s 580ms/step - loss: 0.6933 - accuracy: 0.4773 - val_loss: 0.6935 - val_accuracy: 0.4500
# Epoch 31/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5114WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 31: Test Accuracy = 0.5000, Test Loss = 0.6932
# 22/22 [==============================] - 13s 576ms/step - loss: 0.6932 - accuracy: 0.5114 - val_loss: 0.6935 - val_accuracy: 0.4500
# Epoch 32/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.4886WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 32: Test Accuracy = 0.5000, Test Loss = 0.6932
# 22/22 [==============================] - 12s 554ms/step - loss: 0.6935 - accuracy: 0.4886 - val_loss: 0.6936 - val_accuracy: 0.4500
# Epoch 33/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.4830WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 33: Test Accuracy = 0.5000, Test Loss = 0.6931
# 22/22 [==============================] - 12s 546ms/step - loss: 0.6934 - accuracy: 0.4830 - val_loss: 0.6933 - val_accuracy: 0.4500
# Epoch 34/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.4886WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 34: Test Accuracy = 0.5000, Test Loss = 0.6932
# 22/22 [==============================] - 12s 547ms/step - loss: 0.6935 - accuracy: 0.4886 - val_loss: 0.6934 - val_accuracy: 0.4500
# Epoch 35/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5170WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 35: Test Accuracy = 0.5000, Test Loss = 0.6932
# 22/22 [==============================] - 12s 565ms/step - loss: 0.6932 - accuracy: 0.5170 - val_loss: 0.6938 - val_accuracy: 0.4500
# Epoch 36/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5114WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 36: Test Accuracy = 0.5000, Test Loss = 0.6932
# 22/22 [==============================] - 12s 572ms/step - loss: 0.6931 - accuracy: 0.5114 - val_loss: 0.6937 - val_accuracy: 0.4500
# Epoch 37/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.4545WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 37: Test Accuracy = 0.5000, Test Loss = 0.6932
# 22/22 [==============================] - 12s 555ms/step - loss: 0.6936 - accuracy: 0.4545 - val_loss: 0.6936 - val_accuracy: 0.4500
# Epoch 38/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5000WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 38: Test Accuracy = 0.5000, Test Loss = 0.6931
# 22/22 [==============================] - 13s 580ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6934 - val_accuracy: 0.4500
# Epoch 39/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.4830WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 39: Test Accuracy = 0.5000, Test Loss = 0.6932
# 22/22 [==============================] - 12s 550ms/step - loss: 0.6935 - accuracy: 0.4830 - val_loss: 0.6936 - val_accuracy: 0.4500
# Epoch 40/40
# 22/22 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.4943WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# Epoch 40: Test Accuracy = 0.5000, Test Loss = 0.6931
# 22/22 [==============================] - 12s 546ms/step - loss: 0.6933 - accuracy: 0.4943 - val_loss: 0.6933 - val_accuracy: 0.4500
# 10/11 [==========================>...] - ETA: 0s - loss: 0.6931 - accuracy: 0.5000WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# 11/11 [==============================] - 3s 288ms/step - loss: 0.6931 - accuracy: 0.5000
# 10/11 [==========================>...] - ETA: 0sWARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# 11/11 [==============================] - 3s 287ms/step
#
# 訓練完成 - epochs: 40, batch_size: 8
# 訓練集準確率: 0.4943, 損失: 0.6933
# 驗證集準確率: 0.4500, 損失: 0.6933
# 測試集準確率: 0.5000, 損失: 0.6931
# 整體準確率(不分性別): 0.5000
# 訓練時間: 0:08:14
# 各類別準確率:
#   men: 0.0000
#   women: 1.0000
#
# 開始訓練 - epochs: 40, batch_size: 16
# Found 176 images belonging to 2 classes.
# Found 44 images belonging to 2 classes.
# Found 80 images belonging to 2 classes.
# Epoch 1/40
# 11/11 [==============================] - ETA: 0s - loss: 1.0141 - accuracy: 0.4716WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 1: Test Accuracy = 0.5125, Test Loss = 0.6927
# 11/11 [==============================] - 13s 1s/step - loss: 1.0141 - accuracy: 0.4716 - val_loss: 0.6886 - val_accuracy: 0.6875
# Epoch 2/40
# 11/11 [==============================] - ETA: 0s - loss: 0.6938 - accuracy: 0.4830WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# ...
# Epoch 33: Test Accuracy = 0.5750, Test Loss = 1.0342
# 11/11 [==============================] - 12s 1s/step - loss: 0.3724 - accuracy: 0.7898 - val_loss: 0.5481 - val_accuracy: 0.7500
# Epoch 34/60
# 11/11 [==============================] - ETA: 0s - loss: 0.3619 - accuracy: 0.8239WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 34: Test Accuracy = 0.6000, Test Loss = 1.3905
# 11/11 [==============================] - 12s 1s/step - loss: 0.3619 - accuracy: 0.8239 - val_loss: 0.4633 - val_accuracy: 0.7188
# Epoch 35/60
# 11/11 [==============================] - ETA: 0s - loss: 0.3462 - accuracy: 0.8352WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 35: Test Accuracy = 0.5875, Test Loss = 1.1273
# 11/11 [==============================] - 12s 1s/step - loss: 0.3462 - accuracy: 0.8352 - val_loss: 0.6821 - val_accuracy: 0.5625
# Epoch 36/60
# 11/11 [==============================] - ETA: 0s - loss: 0.3721 - accuracy: 0.8239WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 36: Test Accuracy = 0.6500, Test Loss = 1.2276
# 11/11 [==============================] - 12s 1s/step - loss: 0.3721 - accuracy: 0.8239 - val_loss: 0.5949 - val_accuracy: 0.7500
# Epoch 37/60
# 11/11 [==============================] - ETA: 0s - loss: 0.3399 - accuracy: 0.8011WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 37: Test Accuracy = 0.6250, Test Loss = 1.5285
# 11/11 [==============================] - 13s 1s/step - loss: 0.3399 - accuracy: 0.8011 - val_loss: 0.7082 - val_accuracy: 0.6250
# Epoch 38/60
# 11/11 [==============================] - ETA: 0s - loss: 0.3215 - accuracy: 0.8125WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 38: Test Accuracy = 0.6250, Test Loss = 1.5809
# 11/11 [==============================] - 12s 1s/step - loss: 0.3215 - accuracy: 0.8125 - val_loss: 1.0182 - val_accuracy: 0.5625
# Epoch 39/60
# 11/11 [==============================] - ETA: 0s - loss: 0.3593 - accuracy: 0.8125WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 39: Test Accuracy = 0.6000, Test Loss = 1.1971
# 11/11 [==============================] - 13s 1s/step - loss: 0.3593 - accuracy: 0.8125 - val_loss: 0.5517 - val_accuracy: 0.6250
# Epoch 40/60
# 11/11 [==============================] - ETA: 0s - loss: 0.3945 - accuracy: 0.8239WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 40: Test Accuracy = 0.6250, Test Loss = 1.1921
# 11/11 [==============================] - 12s 1s/step - loss: 0.3945 - accuracy: 0.8239 - val_loss: 0.7286 - val_accuracy: 0.5625
# Epoch 41/60
# 11/11 [==============================] - ETA: 0s - loss: 0.3119 - accuracy: 0.8580WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 41: Test Accuracy = 0.6375, Test Loss = 1.3782
# 11/11 [==============================] - 12s 1s/step - loss: 0.3119 - accuracy: 0.8580 - val_loss: 0.9554 - val_accuracy: 0.5625
# Epoch 42/60
# 11/11 [==============================] - ETA: 0s - loss: 0.3071 - accuracy: 0.8352WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 42: Test Accuracy = 0.6500, Test Loss = 1.6371
# 11/11 [==============================] - 12s 1s/step - loss: 0.3071 - accuracy: 0.8352 - val_loss: 0.7991 - val_accuracy: 0.6250
# Epoch 43/60
# 11/11 [==============================] - ETA: 0s - loss: 0.3136 - accuracy: 0.8182WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 43: Test Accuracy = 0.6125, Test Loss = 1.0857
# 11/11 [==============================] - 13s 1s/step - loss: 0.3136 - accuracy: 0.8182 - val_loss: 0.6858 - val_accuracy: 0.5625
# Epoch 44/60
# 11/11 [==============================] - ETA: 0s - loss: 0.2319 - accuracy: 0.8920WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 44: Test Accuracy = 0.6500, Test Loss = 1.3291
# 11/11 [==============================] - 12s 1s/step - loss: 0.2319 - accuracy: 0.8920 - val_loss: 0.7315 - val_accuracy: 0.6250
# Epoch 45/60
# 11/11 [==============================] - ETA: 0s - loss: 0.2693 - accuracy: 0.8693WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 45: Test Accuracy = 0.6375, Test Loss = 1.5969
# 11/11 [==============================] - 12s 1s/step - loss: 0.2693 - accuracy: 0.8693 - val_loss: 0.8412 - val_accuracy: 0.6562
# Epoch 46/60
# 11/11 [==============================] - ETA: 0s - loss: 0.2650 - accuracy: 0.8864WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 46: Test Accuracy = 0.6500, Test Loss = 1.3892
# 11/11 [==============================] - 13s 1s/step - loss: 0.2650 - accuracy: 0.8864 - val_loss: 0.7684 - val_accuracy: 0.5938
# Epoch 47/60
# 11/11 [==============================] - ETA: 0s - loss: 0.2068 - accuracy: 0.9318WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 47: Test Accuracy = 0.6500, Test Loss = 1.5019
# 11/11 [==============================] - 14s 1s/step - loss: 0.2068 - accuracy: 0.9318 - val_loss: 1.3170 - val_accuracy: 0.5312
# Epoch 48/60
# 11/11 [==============================] - ETA: 0s - loss: 0.2686 - accuracy: 0.8920WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 48: Test Accuracy = 0.6375, Test Loss = 1.5766
# 11/11 [==============================] - 13s 1s/step - loss: 0.2686 - accuracy: 0.8920 - val_loss: 1.1136 - val_accuracy: 0.6562
# Epoch 49/60
# 11/11 [==============================] - ETA: 0s - loss: 0.2378 - accuracy: 0.9034WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 49: Test Accuracy = 0.6000, Test Loss = 1.2416
# 11/11 [==============================] - 12s 1s/step - loss: 0.2378 - accuracy: 0.9034 - val_loss: 0.9381 - val_accuracy: 0.5625
# Epoch 50/60
# 11/11 [==============================] - ETA: 0s - loss: 0.3010 - accuracy: 0.8920WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 50: Test Accuracy = 0.6500, Test Loss = 1.6597
# 11/11 [==============================] - 12s 1s/step - loss: 0.3010 - accuracy: 0.8920 - val_loss: 1.6763 - val_accuracy: 0.5625
# Epoch 51/60
# 11/11 [==============================] - ETA: 0s - loss: 0.3107 - accuracy: 0.8693WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 51: Test Accuracy = 0.6750, Test Loss = 1.3950
# 11/11 [==============================] - 12s 1s/step - loss: 0.3107 - accuracy: 0.8693 - val_loss: 1.2137 - val_accuracy: 0.5625
# Epoch 52/60
# 11/11 [==============================] - ETA: 0s - loss: 0.2342 - accuracy: 0.9034WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 52: Test Accuracy = 0.6250, Test Loss = 1.2132
# 11/11 [==============================] - 12s 1s/step - loss: 0.2342 - accuracy: 0.9034 - val_loss: 1.0393 - val_accuracy: 0.5938
# Epoch 53/60
# 11/11 [==============================] - ETA: 0s - loss: 0.1911 - accuracy: 0.9318WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 53: Test Accuracy = 0.6250, Test Loss = 1.5704
# 11/11 [==============================] - 12s 1s/step - loss: 0.1911 - accuracy: 0.9318 - val_loss: 1.2335 - val_accuracy: 0.6250
# Epoch 54/60
# 11/11 [==============================] - ETA: 0s - loss: 0.1917 - accuracy: 0.9148WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 54: Test Accuracy = 0.6000, Test Loss = 1.6257
# 11/11 [==============================] - 12s 1s/step - loss: 0.1917 - accuracy: 0.9148 - val_loss: 1.4272 - val_accuracy: 0.5000
# Epoch 55/60
# 11/11 [==============================] - ETA: 0s - loss: 0.2406 - accuracy: 0.9261WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 55: Test Accuracy = 0.6000, Test Loss = 2.0180
# 11/11 [==============================] - 12s 1s/step - loss: 0.2406 - accuracy: 0.9261 - val_loss: 0.9976 - val_accuracy: 0.5938
# Epoch 56/60
# 11/11 [==============================] - ETA: 0s - loss: 0.2159 - accuracy: 0.9375WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 56: Test Accuracy = 0.6250, Test Loss = 1.6346
# 11/11 [==============================] - 12s 1s/step - loss: 0.2159 - accuracy: 0.9375 - val_loss: 1.3568 - val_accuracy: 0.5625
# Epoch 57/60
# 11/11 [==============================] - ETA: 0s - loss: 0.1829 - accuracy: 0.9261WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 57: Test Accuracy = 0.6625, Test Loss = 1.6366
# 11/11 [==============================] - 12s 1s/step - loss: 0.1829 - accuracy: 0.9261 - val_loss: 1.2462 - val_accuracy: 0.5625
# Epoch 58/60
# 11/11 [==============================] - ETA: 0s - loss: 0.1781 - accuracy: 0.9148WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 58: Test Accuracy = 0.6500, Test Loss = 1.4475
# 11/11 [==============================] - 12s 1s/step - loss: 0.1781 - accuracy: 0.9148 - val_loss: 1.2324 - val_accuracy: 0.5312
# Epoch 59/60
# 11/11 [==============================] - ETA: 0s - loss: 0.1810 - accuracy: 0.9205WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 59: Test Accuracy = 0.6875, Test Loss = 1.7308
# 11/11 [==============================] - 12s 1s/step - loss: 0.1810 - accuracy: 0.9205 - val_loss: 1.1128 - val_accuracy: 0.6562
# Epoch 60/60
# 11/11 [==============================] - ETA: 0s - loss: 0.1942 - accuracy: 0.9205WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# Epoch 60: Test Accuracy = 0.6625, Test Loss = 1.5687
# 11/11 [==============================] - 12s 1s/step - loss: 0.1942 - accuracy: 0.9205 - val_loss: 1.3164 - val_accuracy: 0.5312
# 5/6 [========================>.....] - ETA: 0s - loss: 1.5687 - accuracy: 0.6625WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# 6/6 [==============================] - 3s 510ms/step - loss: 1.5687 - accuracy: 0.6625
# 5/6 [========================>.....] - ETA: 0sWARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# 6/6 [==============================] - 3s 560ms/step
#
# 訓練完成 - epochs: 60, batch_size: 16
# 訓練集準確率: 0.9205, 損失: 0.1942
# 驗證集準確率: 0.5312, 損失: 1.3164
# 測試集準確率: 0.6625, 損失: 1.5687
# 整體準確率(不分性別): 0.6625
# 訓練時間: 0:12:25
# 各類別準確率:
#   men: 0.6750
#   women: 0.6500

# %%
# 創建並展示結果摘要
print("\n實驗結果摘要:")
print("-" * 132)
print(f"{'參數組合':<20}{'訓練準確率':<12}{'驗證準確率':<12}{'測試準確率':<12}{'訓練損失':<12}{'驗證損失':<12}{'測試損失':<12}{'訓練時間':<12}{'整體準確率':<12}{'men準確率':<12}{'women準確率':<12}")
print("-" * 132)
# Out:
# 實驗結果摘要:
# ------------------------------------------------------------------------------------------------------------------------------------
# 參數組合                訓練準確率       驗證準確率       測試準確率       訓練損失        驗證損失        測試損失        訓練時間        整體準確率       men準確率      women準確率
# ------------------------------------------------------------------------------------------------------------------------------------

# %%
# 繪製三張圖表：
# 1. Train 和 Val Accuracy
# 2. Train 和 Test Accuracy
# 3. Train 和 Test Loss
for key, data in results.items():
    plt.figure(figsize=(15, 5))
    
    # 第一張圖：Train 和 Val Accuracy
    plt.subplot(1, 3, 1)
    epochs_count = len(data['history']['accuracy'])
    epochs_range = range(1, epochs_count + 1)
    plt.plot(epochs_range, data['history']['accuracy'], '-', label=f"{key} (train)")
    if 'val_accuracy' in data['history']:
        plt.plot(epochs_range, data['history']['val_accuracy'], '--', label=f"{key} (val)")
    plt.title(f'{key} - Train and Val Acc')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')
    plt.grid(True)
    
    # 第二張圖：Train 和 Test Accuracy
    plt.subplot(1, 3, 2)
    epochs_count = len(data['history']['accuracy'])
    epochs_range = range(1, epochs_count + 1)
    plt.plot(epochs_range, data['history']['accuracy'], '-', label=f"{key} (train)")
    plt.plot(epochs_range, data['test_acc_history'], '--', label=f"{key} (test)")
    plt.title(f'{key} - Train and Test Acc')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')
    plt.grid(True)
    
    # 第三張圖：Train 和 Test Loss
    plt.subplot(1, 3, 3)
    epochs_count = len(data['history']['loss'])
    epochs_range = range(1, epochs_count + 1)
    plt.plot(epochs_range, data['history']['loss'], '-', label=f"{key} (train)")
    plt.plot(epochs_range, data['test_loss_history'], '--', label=f"{key} (test)")
    plt.title(f'{key} - Train and Test Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.grid(True)
    
    plt.tight_layout()
    filename = f'regularization_training_{key.replace(" ", "_")}.png'
    filepath = os.path.join(output_dir, filename)
    plt.savefig(filepath)
    print(f"參數組合 '{key}' 的訓練過程圖表已保存至: {filepath}")
# Out:
# 參數組合 'epochs_20_batch_8' 的訓練過程圖表已保存至: D:/桌面/ML/temp/MLWORK/regularization\regularization_training_epochs_20_batch_8.png
# 參數組合 'epochs_20_batch_16' 的訓練過程圖表已保存至: D:/桌面/ML/temp/MLWORK/regularization\regularization_training_epochs_20_batch_16.png
# 參數組合 'epochs_40_batch_8' 的訓練過程圖表已保存至: D:/桌面/ML/temp/MLWORK/regularization\regularization_training_epochs_40_batch_8.png
# 參數組合 'epochs_40_batch_16' 的訓練過程圖表已保存至: D:/桌面/ML/temp/MLWORK/regularization\regularization_training_epochs_40_batch_16.png
# 參數組合 'epochs_60_batch_8' 的訓練過程圖表已保存至: D:/桌面/ML/temp/MLWORK/regularization\regularization_training_epochs_60_batch_8.png
# 參數組合 'epochs_60_batch_16' 的訓練過程圖表已保存至: D:/桌面/ML/temp/MLWORK/regularization\regularization_training_epochs_60_batch_16.png

# %%
# 建立比較表格，以DataFrame方式顯示不同組合間的性能
comparison_table = pd.DataFrame({
    'Epochs_Batch': [key for key in results.keys()],
    'Test Acc': [results[key]['test_acc'] for key in results.keys()],
    'Train Acc': [results[key]['train_acc'] for key in results.keys()],
    'Val Acc': [results[key]['val_acc'] for key in results.keys()],
    'Test Loss': [results[key]['test_loss'] for key in results.keys()],
    'Train Loss': [results[key]['train_loss'] for key in results.keys()],
    'Val Loss': [results[key]['val_loss'] for key in results.keys()],
    'Training Time': [results[key]['formatted_time'] for key in results.keys()],
    'Overall Acc': [results[key]['overall_accuracy'] for key in results.keys()],
    'Men Acc': [results[key]['class_accuracies'].get('men', 0.0) for key in results.keys()],
    'Women Acc': [results[key]['class_accuracies'].get('women', 0.0) for key in results.keys()],
})
print("\n參數組合比較表:")
print(comparison_table.sort_values(by='Test Acc', ascending=False))
# Out:
# 參數組合比較表:
#          Epochs_Batch  Test Acc  Train Acc  Val Acc  Test Loss  Train Loss  \
# 5  epochs_60_batch_16    0.6625   0.920455  0.53125   1.568673    0.194219
# 0   epochs_20_batch_8    0.5000   0.539773  0.55000   0.693147    0.693078
# 1  epochs_20_batch_16    0.5000   0.477273  0.68750   0.693147    0.693632
# 2   epochs_40_batch_8    0.5000   0.494318  0.45000   0.693149    0.693285
# 3  epochs_40_batch_16    0.5000   0.568182  0.31250   0.693148    0.692653
# 4   epochs_60_batch_8    0.5000   0.511364  0.55000   0.693148    0.692577
#
#    Val Loss Training Time  Overall Acc  Men Acc  Women Acc
# 5  1.316391       0:12:25       0.6625    0.675       0.65
# 0  0.693120       0:04:09       0.5000    1.000       0.00
# 1  0.692175       0:04:14       0.5000    1.000       0.00
# 2  0.693321       0:08:14       0.5000    0.000       1.00
# 3  0.693581       0:08:15       0.5000    0.000       1.00
# 4  0.693068       0:12:14       0.5000    1.000       0.00
