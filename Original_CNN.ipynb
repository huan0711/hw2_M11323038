# %%
import numpy as np 
import os
import tensorflow  as tf
from keras.models import Sequential
from keras.layers import Dense,Conv2D,Flatten,MaxPooling2D,UpSampling2D,InputLayer,Reshape

from keras.utils import image_dataset_from_directory
from keras.layers import Dropout,Activation,BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array
from tensorflow.keras.utils import array_to_img
import matplotlib.pyplot as plt

from keras.layers import LeakyReLU
from pathlib import Path
from skimage.io import imread
from skimage.transform import resize
from sklearn.utils import Bunch
import math
import pandas as pd
import datetime
import time
import csv
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import time
import datetime
import os
from PIL import Image
import sys

# %%
# 設定圖片大小和路徑
img_rows, img_cols = 256,256  # 縮小圖片尺寸以減少記憶體使用
train_data_dir = "C:/Users/user/Desktop/MLwork2/train"
test_data_dir = "C:/Users/user/Desktop/MLwork2/test"

# %%
# 準備測試不同的參數
epochs_list = [20,40,60]
batch_size_list = [8, 16]

# %%
# 對每種參數組合進行實驗
results = {}  # 用來存儲所有結果的字典
output_dir = 'C:/Users/user/Desktop/MLWORK/original_20_40_60'
csv_filename = 'original_training_results.csv'
detailed_csv_filename = os.path.join(output_dir, 'original_detailed_training_results.csv')
summary_csv_filename = os.path.join(output_dir, 'original_summary_results.csv')
plot_filename = os.path.join(output_dir, 'original_training_comparison.png')

os.makedirs(output_dir, exist_ok=True)

# 創建基本CSV文件並寫入標題
fieldnames = ['epochs', 'batch_size', 'train_acc', 'val_acc', 'test_acc', 
              'train_loss', 'val_loss', 'test_loss', 'training_time', 
              'overall_accuracy', 'men_accuracy', 'women_accuracy']

# 創建基本結果CSV
with open(csv_filename, 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()

# 創建詳細結果CSV (每個epoch的數據)
with open(detailed_csv_filename, 'w', newline='') as csvfile:
    detailed_fieldnames = ['combination', 'epoch', 'train_acc', 'val_acc', 'train_loss', 'val_loss']
    writer = csv.DictWriter(csvfile, fieldnames=detailed_fieldnames)
    writer.writeheader()

# %%
# 這邊只是輸出模型架構不然後面寫在迴圈裡會輸出很多次
reference_model = Sequential()

reference_model.add(Conv2D(32, (3,3), padding="same", input_shape=(img_rows,img_cols,3)))
reference_model.add(Activation("relu"))
reference_model.add(MaxPooling2D(pool_size=(3,3)))

reference_model.add(Conv2D(64, (3,3), padding="same"))
reference_model.add(Activation("relu"))

reference_model.add(Conv2D(64, (3,3), padding="same"))
reference_model.add(Activation("relu"))
reference_model.add(MaxPooling2D(pool_size=(2,2)))


reference_model.add(Conv2D(128, (3,3), padding="same"))
reference_model.add(Activation("relu"))


reference_model.add(Conv2D(128, (3,3), padding="same"))
reference_model.add(Activation("relu"))
reference_model.add(MaxPooling2D(pool_size=(2,2)))

reference_model.add(Flatten())
reference_model.add(Dense(1024, activation='relu'))
reference_model.add(Dense(1, activation='sigmoid'))

# 只顯示一次模型摘要
print("\n模型架構:")
reference_model.summary()
# Out:
# 模型架構:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 32)      896
#
#  activation (Activation)     (None, 256, 256, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 85, 85, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 85, 85, 64)        18496
#
#  activation_1 (Activation)   (None, 85, 85, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 85, 85, 64)        36928
#
#  activation_2 (Activation)   (None, 85, 85, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 42, 42, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 42, 42, 128)       73856
#
#  activation_3 (Activation)   (None, 42, 42, 128)       0
#
#  conv2d_4 (Conv2D)           (None, 42, 42, 128)       147584
#
#  activation_4 (Activation)   (None, 42, 42, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 21, 21, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 56448)             0
#
#  dense (Dense)               (None, 1024)              57803776
#
#  dense_1 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 58,082,561
# Trainable params: 58,082,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 對每種參數組合進行實驗
for epochs in epochs_list:
    for batch_size in batch_size_list:
        print(f"\n開始訓練 - epochs: {epochs}, batch_size: {batch_size}")
        
        # 資料增強和標準化
        train_datagen = ImageDataGenerator(
            validation_split=0.2,
            rescale=1./255,
        )
        
        validation_datagen = ImageDataGenerator(rescale=1./255)
        test_datagen = ImageDataGenerator(rescale=1./255)
        
        train_generator = train_datagen.flow_from_directory(
            train_data_dir,
            target_size=(img_rows, img_cols),
            batch_size=batch_size,
            class_mode='binary',
            shuffle=True,
            subset='training'
        )
        
        validation_generator = train_datagen.flow_from_directory(
            train_data_dir,
            batch_size=batch_size,
            target_size=(img_rows, img_cols),
            class_mode='binary',
            shuffle=True,
            subset='validation'
        )
        
        test_generator = test_datagen.flow_from_directory(
            test_data_dir,
            target_size=(img_rows, img_cols),
            batch_size=batch_size,
            class_mode='binary',
            shuffle=False
        )
        
        # 模型
        model = Sequential()
        
        model.add(Conv2D(32, (3,3), padding="same", input_shape=(img_rows,img_cols,3)))
        model.add(Activation("relu"))
        model.add(MaxPooling2D(pool_size=(3,3)))

        model.add(Conv2D(64, (3,3), padding="same"))
        model.add(Activation("relu"))

        model.add(Conv2D(64, (3,3), padding="same"))
        model.add(Activation("relu"))
        model.add(MaxPooling2D(pool_size=(2,2)))


        model.add(Conv2D(128, (3,3), padding="same"))
        model.add(Activation("relu"))


        model.add(Conv2D(128, (3,3), padding="same"))
        model.add(Activation("relu"))
        model.add(MaxPooling2D(pool_size=(2,2)))


        model.add(Flatten())
        model.add(Dense(1024, activation='relu'))
        model.add(Dense(1, activation='sigmoid'))
        
        model.compile(
            loss='binary_crossentropy',
            optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
            metrics=['accuracy']
        )
        
        # 記錄時間
        start_time = time.time()
        
        # 訓練模型
        history = model.fit(
            train_generator,
            steps_per_epoch=train_generator.samples // batch_size,
            epochs=epochs,
            validation_data=validation_generator,
            validation_steps=validation_generator.samples // batch_size
        )
        
        # 計算時間
        end_time = time.time()
        training_time = end_time - start_time
        formatted_time = str(datetime.timedelta(seconds=int(training_time)))
        
        # 在測試集上評估模型
        test_loss, test_acc = model.evaluate(
            test_generator,
            steps=test_generator.samples // batch_size + 1
        )
        
        # 計算每個類別的準確率
        y_pred = model.predict(test_generator, steps=test_generator.samples // batch_size + 1)
        y_pred_classes = (y_pred > 0.5).astype(int).flatten()
        
        # 獲取真實標籤
        test_generator.reset()
        y_true = test_generator.classes
        
         # 計算整體準確率（不分性別）
        overall_accuracy = np.mean(y_pred_classes == y_true)
        
        # 計算每個類別的準確率
        class_accuracies = {}
        for class_idx, class_name in enumerate(test_generator.class_indices.keys()):
            # 找出屬於該類別的樣本
            class_samples = np.where(y_true == class_idx)[0]
            if len(class_samples) > 0:
                # 計算該類別的準確率
                class_correct = np.sum(y_pred_classes[class_samples] == class_idx)
                class_accuracy = class_correct / len(class_samples)
                class_accuracies[class_name] = class_accuracy
            else:
                class_accuracies[class_name] = 0.0
        
        # 獲取最終訓練和驗證準確率/損失
        final_train_acc = history.history['accuracy'][-1]
        final_train_loss = history.history['loss'][-1]
        final_val_acc = history.history['val_accuracy'][-1] if 'val_accuracy' in history.history else None
        final_val_loss = history.history['val_loss'][-1] if 'val_loss' in history.history else None
        
        # 儲存結果
        key = f"epochs_{epochs}_batch_{batch_size}"
        results[key] = {
            'history': history.history,
            'test_acc': test_acc,
            'test_loss': test_loss,
            'training_time': training_time,
            'formatted_time': formatted_time,
            'overall_accuracy': overall_accuracy,
            'class_accuracies': class_accuracies,
            'train_acc': final_train_acc,
            'train_loss': final_train_loss,
            'val_acc': final_val_acc,
            'val_loss': final_val_loss
        }
        
        # 輸出當前實驗結果
        print(f"\n訓練完成 - epochs: {epochs}, batch_size: {batch_size}")
        print(f"訓練集準確率: {final_train_acc:.4f}, 損失: {final_train_loss:.4f}")
        print(f"驗證集準確率: {final_val_acc:.4f}, 損失: {final_val_loss:.4f}")
        print(f"測試集準確率: {test_acc:.4f}, 損失: {test_loss:.4f}")
        print(f"整體準確率(不分性別): {overall_accuracy:.4f}")
        print(f"訓練時間: {formatted_time}")
        print("各類別準確率:")
        for class_name, accuracy in class_accuracies.items():
            print(f"  {class_name}: {accuracy:.4f}")
            
        # 將結果寫入CSV
        with open(csv_filename, 'a', newline='') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            writer.writerow({
                'epochs': epochs,
                'batch_size': batch_size,
                'train_acc': f"{final_train_acc:.4f}",
                'val_acc': f"{final_val_acc:.4f}" if final_val_acc is not None else None,
                'test_acc': f"{test_acc:.4f}",
                'train_loss': f"{final_train_loss:.4f}",
                'val_loss': f"{final_val_loss:.4f}" if final_val_loss is not None else None,
                'test_loss': f"{test_loss:.4f}",
                'training_time': formatted_time,
                'overall_accuracy': f"{overall_accuracy:.4f}",
                'men_accuracy': f"{class_accuracies.get('men', 0.0):.4f}",
                'women_accuracy': f"{class_accuracies.get('women', 0.0):.4f}"
            })
            
        # 保存每個epoch的詳細資訊
        with open(detailed_csv_filename, 'a', newline='') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=detailed_fieldnames)
            for i in range(len(history.history['accuracy'])):
                writer.writerow({
                    'combination': key,
                    'epoch': i+1,
                    'train_acc': f"{history.history['accuracy'][i]:.4f}",
                    'val_acc': f"{history.history['val_accuracy'][i]:.4f}" if 'val_accuracy' in history.history else None,
                    'train_loss': f"{history.history['loss'][i]:.4f}",
                    'val_loss': f"{history.history['val_loss'][i]:.4f}" if 'val_loss' in history.history else None
                })
# Out:
# 開始訓練 - epochs: 20, batch_size: 8
# Found 176 images belonging to 2 classes.
# Found 44 images belonging to 2 classes.
# Found 80 images belonging to 2 classes.
# Epoch 1/20
# 22/22 [==============================] - 16s 561ms/step - loss: 0.8561 - accuracy: 0.4773 - val_loss: 0.6919 - val_accuracy: 0.4750
# Epoch 2/20
# 22/22 [==============================] - 11s 489ms/step - loss: 0.7013 - accuracy: 0.4943 - val_loss: 0.6938 - val_accuracy: 0.4750
# Epoch 3/20
# 22/22 [==============================] - 11s 496ms/step - loss: 0.6867 - accuracy: 0.5455 - val_loss: 0.6917 - val_accuracy: 0.5250
# Epoch 4/20
# 22/22 [==============================] - 11s 487ms/step - loss: 0.6923 - accuracy: 0.5795 - val_loss: 0.6908 - val_accuracy: 0.5750
# Epoch 5/20
# 22/22 [==============================] - 11s 501ms/step - loss: 0.6672 - accuracy: 0.6023 - val_loss: 0.7046 - val_accuracy: 0.4500
# Epoch 6/20
# 22/22 [==============================] - 11s 494ms/step - loss: 0.6159 - accuracy: 0.6705 - val_loss: 0.8471 - val_accuracy: 0.5500
# Epoch 7/20
# 22/22 [==============================] - 11s 481ms/step - loss: 0.5303 - accuracy: 0.6989 - val_loss: 1.1675 - val_accuracy: 0.5000
# Epoch 8/20
# 22/22 [==============================] - 11s 477ms/step - loss: 0.4008 - accuracy: 0.8466 - val_loss: 0.8801 - val_accuracy: 0.5750
# Epoch 9/20
# 22/22 [==============================] - 11s 483ms/step - loss: 0.2646 - accuracy: 0.8864 - val_loss: 1.9672 - val_accuracy: 0.6000
# Epoch 10/20
# 22/22 [==============================] - 11s 502ms/step - loss: 0.3620 - accuracy: 0.8580 - val_loss: 0.9604 - val_accuracy: 0.5250
# Epoch 11/20
# 22/22 [==============================] - 11s 506ms/step - loss: 0.1723 - accuracy: 0.9205 - val_loss: 1.1641 - val_accuracy: 0.5000
# Epoch 12/20
# 22/22 [==============================] - 11s 487ms/step - loss: 0.1340 - accuracy: 0.9545 - val_loss: 1.2492 - val_accuracy: 0.4500
# Epoch 13/20
# 22/22 [==============================] - 11s 473ms/step - loss: 0.0944 - accuracy: 0.9659 - val_loss: 1.4536 - val_accuracy: 0.5250
# Epoch 14/20
# 22/22 [==============================] - 11s 501ms/step - loss: 0.0347 - accuracy: 0.9886 - val_loss: 2.4114 - val_accuracy: 0.4000
# Epoch 15/20
# 22/22 [==============================] - 11s 499ms/step - loss: 0.0192 - accuracy: 0.9943 - val_loss: 2.0336 - val_accuracy: 0.4250
# Epoch 16/20
# 22/22 [==============================] - 11s 516ms/step - loss: 0.0137 - accuracy: 0.9943 - val_loss: 2.5686 - val_accuracy: 0.4500
# Epoch 17/20
# 22/22 [==============================] - 11s 482ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 2.9029 - val_accuracy: 0.4500
# Epoch 18/20
# 22/22 [==============================] - 11s 489ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 3.4214 - val_accuracy: 0.5500
# Epoch 19/20
# 22/22 [==============================] - 11s 493ms/step - loss: 3.7645e-04 - accuracy: 1.0000 - val_loss: 3.0852 - val_accuracy: 0.4750
# Epoch 20/20
# 22/22 [==============================] - 11s 488ms/step - loss: 1.9892e-04 - accuracy: 1.0000 - val_loss: 3.5206 - val_accuracy: 0.5500
# 10/11 [==========================>...] - ETA: 0s - loss: 4.4459 - accuracy: 0.5875WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# 11/11 [==============================] - 6s 578ms/step - loss: 4.4459 - accuracy: 0.5875
# 10/11 [==========================>...] - ETA: 0sWARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# 11/11 [==============================] - 5s 443ms/step
#
# 訓練完成 - epochs: 20, batch_size: 8
# 訓練集準確率: 1.0000, 損失: 0.0002
# 驗證集準確率: 0.5500, 損失: 3.5206
# 測試集準確率: 0.5875, 損失: 4.4459
# 整體準確率(不分性別): 0.5875
# 訓練時間: 0:03:44
# 各類別準確率:
#   men: 0.5750
#   women: 0.6000
#
# 開始訓練 - epochs: 20, batch_size: 16
# Found 176 images belonging to 2 classes.
# Found 44 images belonging to 2 classes.
# Found 80 images belonging to 2 classes.
# Epoch 1/20
# 11/11 [==============================] - 13s 1s/step - loss: 0.9393 - accuracy: 0.4886 - val_loss: 0.6971 - val_accuracy: 0.4688
# Epoch 2/20
# 11/11 [==============================] - 11s 989ms/step - loss: 0.6966 - accuracy: 0.4830 - val_loss: 0.6639 - val_accuracy: 0.6250
# Epoch 3/20
# 11/11 [==============================] - 11s 1s/step - loss: 0.6959 - accuracy: 0.5398 - val_loss: 0.6924 - val_accuracy: 0.5625
# Epoch 4/20
# 11/11 [==============================] - 11s 982ms/step - loss: 0.6798 - accuracy: 0.6023 - val_loss: 0.7258 - val_accuracy: 0.5000
# Epoch 5/20
# 11/11 [==============================] - 11s 1s/step - loss: 0.6783 - accuracy: 0.5682 - val_loss: 0.6762 - val_accuracy: 0.5625
# Epoch 6/20
# 11/11 [==============================] - 11s 989ms/step - loss: 0.6417 - accuracy: 0.6932 - val_loss: 0.7127 - val_accuracy: 0.5312
# Epoch 7/20
# 11/11 [==============================] - 11s 967ms/step - loss: 0.6053 - accuracy: 0.6875 - val_loss: 0.6896 - val_accuracy: 0.5312
# Epoch 8/20
# 11/11 [==============================] - 11s 987ms/step - loss: 0.5862 - accuracy: 0.6932 - val_loss: 0.9081 - val_accuracy: 0.5625
# Epoch 9/20
# 11/11 [==============================] - 11s 1s/step - loss: 0.5673 - accuracy: 0.7500 - val_loss: 0.7169 - val_accuracy: 0.5312
# Epoch 10/20
# 11/11 [==============================] - 11s 993ms/step - loss: 0.5050 - accuracy: 0.7500 - val_loss: 0.7375 - val_accuracy: 0.5000
# Epoch 11/20
# 11/11 [==============================] - 11s 967ms/step - loss: 0.3920 - accuracy: 0.8125 - val_loss: 0.8347 - val_accuracy: 0.5625
# Epoch 12/20
# 11/11 [==============================] - 11s 1s/step - loss: 0.3373 - accuracy: 0.8693 - val_loss: 1.4370 - val_accuracy: 0.5312
# Epoch 13/20
# 11/11 [==============================] - 11s 999ms/step - loss: 0.2144 - accuracy: 0.9034 - val_loss: 1.3443 - val_accuracy: 0.5625
# Epoch 14/20
# 11/11 [==============================] - 11s 962ms/step - loss: 0.1221 - accuracy: 0.9545 - val_loss: 1.8343 - val_accuracy: 0.5312
# Epoch 15/20
# 11/11 [==============================] - 11s 957ms/step - loss: 0.0557 - accuracy: 0.9830 - val_loss: 3.1324 - val_accuracy: 0.5000
# Epoch 16/20
# 11/11 [==============================] - 11s 978ms/step - loss: 0.0245 - accuracy: 1.0000 - val_loss: 2.9737 - val_accuracy: 0.5000
# Epoch 17/20
# 11/11 [==============================] - 11s 960ms/step - loss: 0.0764 - accuracy: 0.9602 - val_loss: 2.0722 - val_accuracy: 0.5938
# Epoch 18/20
# 11/11 [==============================] - 11s 968ms/step - loss: 0.0647 - accuracy: 0.9830 - val_loss: 3.6649 - val_accuracy: 0.6250
# Epoch 19/20
# 11/11 [==============================] - 11s 964ms/step - loss: 0.0171 - accuracy: 0.9943 - val_loss: 3.5721 - val_accuracy: 0.5938
# Epoch 20/20
# 11/11 [==============================] - 10s 946ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 4.0833 - val_accuracy: 0.5625
# 5/6 [========================>.....] - ETA: 0s - loss: 4.1254 - accuracy: 0.5875WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# 6/6 [==============================] - 5s 723ms/step - loss: 4.1254 - accuracy: 0.5875
# 5/6 [========================>.....] - ETA: 0sWARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# 6/6 [==============================] - 5s 773ms/step
#
# 訓練完成 - epochs: 20, batch_size: 16
# 訓練集準確率: 1.0000, 損失: 0.0079
# 驗證集準確率: 0.5625, 損失: 4.0833
# 測試集準確率: 0.5875, 損失: 4.1254
# 整體準確率(不分性別): 0.5875
# 訓練時間: 0:03:40
# 各類別準確率:
#   men: 0.5500
#   women: 0.6250
#
# 開始訓練 - epochs: 40, batch_size: 8
# Found 176 images belonging to 2 classes.
# Found 44 images belonging to 2 classes.
# Found 80 images belonging to 2 classes.
# Epoch 1/40
# 22/22 [==============================] - 11s 488ms/step - loss: 0.7202 - accuracy: 0.4830 - val_loss: 0.6925 - val_accuracy: 0.5000
# Epoch 2/40
# 22/22 [==============================] - 11s 466ms/step - loss: 0.6937 - accuracy: 0.4602 - val_loss: 0.6932 - val_accuracy: 0.4750
# Epoch 3/40
# 22/22 [==============================] - 11s 486ms/step - loss: 0.6943 - accuracy: 0.5227 - val_loss: 0.6934 - val_accuracy: 0.5000
# Epoch
# 5/6 [========================>.....] - ETA: 0sWARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# 6/6 [==============================] - 5s 759ms/step
#
# 訓練完成 - epochs: 40, batch_size: 16
# 訓練集準確率: 1.0000, 損失: 0.0000
# 驗證集準確率: 0.5000, 損失: 8.3240
# 測試集準確率: 0.5625, 損失: 5.2920
# 整體準確率(不分性別): 0.5625
# 訓練時間: 0:07:07
# 各類別準確率:
#   men: 0.5250
#   women: 0.6000
#
# 開始訓練 - epochs: 60, batch_size: 8
# Found 176 images belonging to 2 classes.
# Found 44 images belonging to 2 classes.
# Found 80 images belonging to 2 classes.
# Epoch 1/60
# 22/22 [==============================] - 12s 500ms/step - loss: 0.8166 - accuracy: 0.4318 - val_loss: 0.6933 - val_accuracy: 0.4000
# Epoch 2/60
# 22/22 [==============================] - 11s 480ms/step - loss: 0.6939 - accuracy: 0.5341 - val_loss: 0.6932 - val_accuracy: 0.4500
# Epoch 3/60
# 22/22 [==============================] - 11s 477ms/step - loss: 0.6927 - accuracy: 0.5398 - val_loss: 0.6913 - val_accuracy: 0.5750
# Epoch 4/60
# 22/22 [==============================] - 11s 463ms/step - loss: 0.6831 - accuracy: 0.5909 - val_loss: 0.6834 - val_accuracy: 0.5250
# Epoch 5/60
# 22/22 [==============================] - 11s 471ms/step - loss: 0.6429 - accuracy: 0.6307 - val_loss: 0.6520 - val_accuracy: 0.6000
# Epoch 6/60
# 22/22 [==============================] - 11s 474ms/step - loss: 0.5748 - accuracy: 0.7102 - val_loss: 0.7946 - val_accuracy: 0.5250
# Epoch 7/60
# 22/22 [==============================] - 11s 473ms/step - loss: 0.4206 - accuracy: 0.8239 - val_loss: 1.0782 - val_accuracy: 0.4500
# Epoch 8/60
# 22/22 [==============================] - 11s 466ms/step - loss: 0.2603 - accuracy: 0.8750 - val_loss: 1.2192 - val_accuracy: 0.4750
# Epoch 9/60
# 22/22 [==============================] - 11s 476ms/step - loss: 0.2528 - accuracy: 0.8807 - val_loss: 1.3477 - val_accuracy: 0.5000
# Epoch 10/60
# 22/22 [==============================] - 11s 477ms/step - loss: 0.0681 - accuracy: 0.9773 - val_loss: 3.7601 - val_accuracy: 0.4500
# Epoch 11/60
# 22/22 [==============================] - 11s 464ms/step - loss: 0.0561 - accuracy: 0.9716 - val_loss: 6.2623 - val_accuracy: 0.4750
# Epoch 12/60
# 22/22 [==============================] - 11s 480ms/step - loss: 0.1235 - accuracy: 0.9602 - val_loss: 2.0500 - val_accuracy: 0.4250
# Epoch 13/60
# 22/22 [==============================] - 11s 467ms/step - loss: 0.1467 - accuracy: 0.9545 - val_loss: 1.7709 - val_accuracy: 0.5250
# Epoch 14/60
# 22/22 [==============================] - 11s 479ms/step - loss: 0.0587 - accuracy: 0.9773 - val_loss: 3.7234 - val_accuracy: 0.4750
# Epoch 15/60
# 22/22 [==============================] - 11s 485ms/step - loss: 0.0395 - accuracy: 0.9830 - val_loss: 4.1041 - val_accuracy: 0.5000
# Epoch 16/60
# 22/22 [==============================] - 11s 482ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 5.4706 - val_accuracy: 0.5750
# Epoch 17/60
# 22/22 [==============================] - 11s 469ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 5.9664 - val_accuracy: 0.5250
# Epoch 18/60
# 22/22 [==============================] - 11s 480ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss:
# 22/22 [==============================] - 11s 468ms/step - loss: 4.6068e-06 - accuracy: 1.0000 - val_loss: 7.6238 - val_accuracy: 0.5250
# Epoch 59/60
# 22/22 [==============================] - 11s 476ms/step - loss: 4.3691e-06 - accuracy: 1.0000 - val_loss: 8.5720 - val_accuracy: 0.5000
# Epoch 60/60
# 22/22 [==============================] - 11s 483ms/step - loss: 4.1424e-06 - accuracy: 1.0000 - val_loss: 7.0962 - val_accuracy: 0.5500
# 10/11 [==========================>...] - ETA: 0s - loss: 7.2941 - accuracy: 0.5125WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# 11/11 [==============================] - 5s 406ms/step - loss: 7.2941 - accuracy: 0.5125
# 10/11 [==========================>...] - ETA: 0sWARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# 11/11 [==============================] - 5s 416ms/step
#
# 訓練完成 - epochs: 60, batch_size: 8
# 訓練集準確率: 1.0000, 損失: 0.0000
# 驗證集準確率: 0.5500, 損失: 7.0962
# 測試集準確率: 0.5125, 損失: 7.2941
# 整體準確率(不分性別): 0.5125
# 訓練時間: 0:10:42
# 各類別準確率:
#   men: 0.4750
#   women: 0.5500
#
# 開始訓練 - epochs: 60, batch_size: 16
# Found 176 images belonging to 2 classes.
# Found 44 images belonging to 2 classes.
# Found 80 images belonging to 2 classes.
# Epoch 1/60
# 11/11 [==============================] - 12s 1s/step - loss: 0.9500 - accuracy: 0.5227 - val_loss: 0.6915 - val_accuracy: 0.5312
# Epoch 2/60
# 11/11 [==============================] - 11s 968ms/step - loss: 0.6954 - accuracy: 0.5170 - val_loss: 0.6940 - val_accuracy: 0.4688
# Epoch 3/60
# 11/11 [==============================] - 11s 965ms/step - loss: 0.7022 - accuracy: 0.5341 - val_loss: 0.6915 - val_accuracy: 0.5312
# Epoch 4/60
# 11/11 [==============================] - 11s 970ms/step - loss: 0.6939 - accuracy: 0.5000 - val_loss: 0.6919 - val_accuracy: 0.5312
# Epoch 5/60
# 11/11 [==============================] - 11s 986ms/step - loss: 0.6931 - accuracy: 0.5057 - val_loss: 0.6965 - val_accuracy: 0.3750
# Epoch 6/60
# 11/11 [==============================] - 11s 965ms/step - loss: 0.6893 - accuracy: 0.6136 - val_loss: 0.6948 - val_accuracy: 0.4062
# Epoch 7/60
# 11/11 [==============================] - 11s 932ms/step - loss: 0.6866 - accuracy: 0.5909 - val_loss: 0.6903 - val_accuracy: 0.5000
# Epoch 8/60
# 11/11 [==============================] - 11s 975ms/step - loss: 0.6848 - accuracy: 0.6193 - val_loss: 0.7024 - val_accuracy: 0.5000
# Epoch 9/60
# 11/11 [==============================] - 11s 976ms/step - loss: 0.6649 - accuracy: 0.5966 - val_loss: 0.6859 - val_accuracy: 0.5625
# Epoch 10/60
# 11/11 [==============================] - 11s 954ms/step - loss: 0.5773 - accuracy: 0.7273 - val_loss: 0.8418 - val_accuracy: 0.4375
# Epoch 11/60
# 11/11 [==============================] - 11s 976ms/step - loss: 0.4871 - accuracy: 0.7670 - val_loss: 0.9779 - val_accuracy: 0.5312
# Epoch 12/60
# 11/11 [==============================] - 11s 965ms/step - loss: 0.3672 - accuracy: 0.8125 - val_loss: 1.2249 - val_accuracy: 0.5938
# Epoch 13/60
# 11/11 [==============================] - 11s 953ms/step - loss: 0.2018 - accuracy: 0.9148 - val_loss: 1.0475 - val_accuracy: 0.5312
# Epoch 14/60
# 11/11 [==============================] - 11s 995ms/step - loss: 0.1673 - accuracy: 0.9375 - val_loss: 2.3552 - val_accuracy: 0.4688
# Epoch 15/60
# 11/11 [==============================] - 11s 936ms/step - loss: 0.1429 - accuracy: 0.9545 - val_loss: 1.5961 - val_accuracy: 0.4375
# Epoch 16/60
# 11/11 [==============================] - 11s 959ms/step - loss: 0.1075 - accuracy: 0.9773 - val_loss: 2.3962 - val_accuracy: 0.3750
# Epoch 17/60
# 11/11 [==============================] - 11s 987ms/step - loss: 0.0376 - accuracy: 0.9830 - val_loss: 3.2885 - val_accuracy: 0.3125
# Epoch 18/60
# 11/11 [==============================] - 11s 994ms/step - loss: 0.0150 - accuracy: 0.9943 - val_loss: 2.9707 - val_accuracy: 0.4375
# Epoch 19/60
# 11/11 [==============================] - 11s 929ms/step - loss: 0.0306 - accuracy: 0.9943 - val_loss: 3.6267 - val_accuracy: 0.4688
# Epoch 20/60
# 11/11 [==============================] - 11s 970ms/step - loss: 0.1007 - accuracy: 0.9602 - val_loss: 1.7743 - val_accuracy: 0.5000
# Epoch 21/60
# 11/11 [==============================] - 11s 1s/step - loss: 0.0881 - accuracy: 0.9659 - val_loss: 2.5653 - val_accuracy: 0.5000
# Epoch 22/60
# 11/11 [==============================] - 11s 967ms/step - loss: 0.0218 - accuracy: 0.9943 - val_loss: 3.1130 - val_accuracy: 0.5312
# Epoch 23/60
# 11/11 [==============================] - 11s 967ms/step - loss: 0.0444 - accuracy: 0.9773 - val_loss: 4.3343 - val_accuracy: 0.5000
# Epoch 24/60
# 11/11 [==============================] - 11s 986ms/step - loss: 0.0740 - accuracy: 0.9773 - val_loss: 3.9401 - val_accuracy: 0.3750
# Epoch 25/60
# 11/11 [==============================] - 11s 976ms/step - loss: 0.0735 - accuracy: 0.9886 - val_loss: 5.7875 - val_accuracy: 0.4688
# Epoch 26/60
# 11/11 [==============================] - 11s 971ms/step - loss: 0.0702 - accuracy: 0.9773 - val_loss: 3.5244 - val_accuracy: 0.5312
# Epoch 27/60
# 11/11 [==============================] - 11s 973ms/step - loss: 0.0881 - accuracy: 0.9659 - val_loss: 2.5291 - val_accuracy: 0.5625
# Epoch 28/60
# 11/11 [==============================] - 11s 985ms/step - loss: 0.0533 - accuracy: 0.9830 - val_loss: 3.8993 - val_accuracy: 0.5312
# Epoch 29/60
# 11/11 [==============================] - 11s 991ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 3.6400 - val_accuracy: 0.5938
# Epoch 30/60
# 11/11 [==============================] - 11s 968ms/step - loss: 0.0115 - accuracy: 0.9943 - val_loss: 4.4224 - val_accuracy: 0.5625
# Epoch 31/60
# 11/11 [==============================] - 11s 955ms/step - loss: 0.0700 - accuracy: 0.9830 - val_loss: 4.9574 - val_accuracy: 0.5312
# Epoch 32/60
# 11/11 [==============================] - 11s 957ms/step - loss: 0.0154 - accuracy: 0.9943 - val_loss: 3.2252 - val_accuracy: 0.5312
# Epoch 33/60
# 11/11 [==============================] - 11s 976ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 3.4522 - val_accuracy: 0.5625
# Epoch 34/60
# 11/11 [==============================] - 11s 955ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 3.9142 - val_accuracy: 0.4375
# Epoch 35/60
# 11/11 [==============================] - 11s 971ms/step - loss: 8.2743e-04 - accuracy: 1.0000 - val_loss: 5.4475 - val_accuracy: 0.4688
# Epoch 36/60
# 11/11 [==============================] - 11s 955ms/step - loss: 5.1543e-04 - accuracy: 1.0000 - val_loss: 5.0415 - val_accuracy: 0.5312
# Epoch 37/60
# 11/11 [==============================] - 11s 993ms/step - loss: 3.0348e-04 - accuracy: 1.0000 - val_loss: 5.2028 - val_accuracy: 0.5312
# Epoch 38/60
# 11/11 [==============================] - 11s 965ms/step - loss: 1.9934e-04 - accuracy: 1.0000 - val_loss: 4.8500 - val_accuracy: 0.5312
# Epoch 39/60
# 11/11 [==============================] - 11s 978ms/step - loss: 1.5500e-04 - accuracy: 1.0000 - val_loss: 4.8681 - val_accuracy: 0.5312
# Epoch 40/60
# 11/11 [==============================] - 11s 978ms/step - loss: 1.3090e-04 - accuracy: 1.0000 - val_loss: 5.8934 - val_accuracy: 0.4688
# Epoch 41/60
# 11/11 [==============================] - 11s 978ms/step - loss: 1.1472e-04 - accuracy: 1.0000 - val_loss: 4.7573 - val_accuracy: 0.5000
# Epoch 42/60
# 11/11 [==============================] - 11s 958ms/step - loss: 1.0061e-04 - accuracy: 1.0000 - val_loss: 6.5636 - val_accuracy: 0.4375
# Epoch 43/60
# 11/11 [==============================] - 11s 952ms/step - loss: 9.1808e-05 - accuracy: 1.0000 - val_loss: 5.7054 - val_accuracy: 0.5312
# Epoch 44/60
# 11/11 [==============================] - 11s 928ms/step - loss: 8.3146e-05 - accuracy: 1.0000 - val_loss: 5.5770 - val_accuracy: 0.5312
# Epoch 45/60
# 11/11 [==============================] - 11s 974ms/step - loss: 7.6216e-05 - accuracy: 1.0000 - val_loss: 6.5863 - val_accuracy: 0.4375
# Epoch 46/60
# 11/11 [==============================] - 11s 943ms/step - loss: 6.8581e-05 - accuracy: 1.0000 - val_loss: 6.7899 - val_accuracy: 0.5000
# Epoch 47/60
# 11/11 [==============================] - 11s 963ms/step - loss: 6.4782e-05 - accuracy: 1.0000 - val_loss: 5.2282 - val_accuracy: 0.5625
# Epoch 48/60
# 11/11 [==============================] - 11s 984ms/step - loss: 5.9232e-05 - accuracy: 1.0000 - val_loss: 5.2290 - val_accuracy: 0.5625
# Epoch 49/60
# 11/11 [==============================] - 11s 939ms/step - loss: 5.5612e-05 - accuracy: 1.0000 - val_loss: 6.0851 - val_accuracy: 0.5000
# Epoch 50/60
# 11/11 [==============================] - 11s 971ms/step - loss: 5.1322e-05 - accuracy: 1.0000 - val_loss: 5.6039 - val_accuracy: 0.5938
# Epoch 51/60
# 11/11 [==============================] - 11s 977ms/step - loss: 4.7880e-05 - accuracy: 1.0000 - val_loss: 4.8298 - val_accuracy: 0.5625
# Epoch 52/60
# 11/11 [==============================] - 11s 963ms/step - loss: 4.4827e-05 - accuracy: 1.0000 - val_loss: 6.4741 - val_accuracy: 0.4688
# Epoch 53/60
# 11/11 [==============================] - 11s 969ms/step - loss: 4.2751e-05 - accuracy: 1.0000 - val_loss: 6.6186 - val_accuracy: 0.5000
# Epoch 54/60
# 11/11 [==============================] - 11s 957ms/step - loss: 3.9838e-05 - accuracy: 1.0000 - val_loss: 5.2993 - val_accuracy: 0.5312
# Epoch 55/60
# 11/11 [==============================] - 11s 983ms/step - loss: 3.7629e-05 - accuracy: 1.0000 - val_loss: 6.5540 - val_accuracy: 0.4688
# Epoch 56/60
# 11/11 [==============================] - 11s 967ms/step - loss: 3.6080e-05 - accuracy: 1.0000 - val_loss: 4.9824 - val_accuracy: 0.6250
# Epoch 57/60
# 11/11 [==============================] - 11s 975ms/step - loss: 3.3888e-05 - accuracy: 1.0000 - val_loss: 6.4913 - val_accuracy: 0.5625
# Epoch 58/60
# 11/11 [==============================] - 11s 956ms/step - loss: 3.2050e-05 - accuracy: 1.0000 - val_loss: 6.3046 - val_accuracy: 0.4688
# Epoch 59/60
# 11/11 [==============================] - 11s 977ms/step - loss: 3.0478e-05 - accuracy: 1.0000 - val_loss: 5.5961 - val_accuracy: 0.5625
# Epoch 60/60
# 11/11 [==============================] - 11s 942ms/step - loss: 2.9080e-05 - accuracy: 1.0000 - val_loss: 5.4468 - val_accuracy: 0.5000
# 5/6 [========================>.....] - ETA: 0s - loss: 5.6280 - accuracy: 0.4875WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# 6/6 [==============================] - 5s 759ms/step - loss: 5.6280 - accuracy: 0.4875
# 5/6 [========================>.....] - ETA: 0sWARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# 6/6 [==============================] - 5s 803ms/step
#
# 訓練完成 - epochs: 60, batch_size: 16
# 訓練集準確率: 1.0000, 損失: 0.0000
# 驗證集準確率: 0.5000, 損失: 5.4468
# 測試集準確率: 0.4875, 損失: 5.6280
# 整體準確率(不分性別): 0.4875
# 訓練時間: 0:10:45
# 各類別準確率:
#   men: 0.5000
#   women: 0.4750

# %%
# 創建並展示結果摘要
print("\n實驗結果摘要:")
print("-" * 132)
print(f"{'參數組合':<20}{'訓練準確率':<12}{'驗證準確率':<12}{'測試準確率':<12}{'訓練損失':<12}{'驗證損失':<12}{'測試損失':<12}{'訓練時間':<12}{'整體準確率':<12}{'men準確率':<12}{'women準確率':<12}")
print("-" * 132)
# Out:
# 實驗結果摘要:
# ------------------------------------------------------------------------------------------------------------------------------------
# 參數組合                訓練準確率       驗證準確率       測試準確率       訓練損失        驗證損失        測試損失        訓練時間        整體準確率       men準確率      women準確率
# ------------------------------------------------------------------------------------------------------------------------------------

# %%
for key, data in results.items():
    print(f"{key:<20}{data['train_acc']:.4f}{'':<4}{data['val_acc']:.4f}{'':<4}{data['test_acc']:.4f}{'':<4}{data['train_loss']:.4f}{'':<4}{data['val_loss']:.4f}{'':<4}{data['test_loss']:.4f}{'':<4}{data['formatted_time']:<12}{data['overall_accuracy']:.4f}{'':<4}{data['class_accuracies'].get('men', 0.0):.4f}{'':<4}{data['class_accuracies'].get('women', 0.0):.4f}")

# 將結果也輸出為DataFrame格式
summary_data = []
for key, data in results.items():
    epochs, batch_size = key.split('_')[1], key.split('_')[3]
    summary_data.append({
        'Epochs': epochs,
        'Batch Size': batch_size,
        'Train Accuracy': f"{data['train_acc']:.4f}",
        'Val Accuracy': f"{data['val_acc']:.4f}" if data['val_acc'] is not None else "N/A",
        'Test Accuracy': f"{data['test_acc']:.4f}",
        'Train Loss': f"{data['train_loss']:.4f}",
        'Val Loss': f"{data['val_loss']:.4f}" if data['val_loss'] is not None else "N/A",
        'Test Loss': f"{data['test_loss']:.4f}",
        'Training Time': data['formatted_time'],
        'Overall Accuracy': f"{data['overall_accuracy']:.4f}",
        'Men Accuracy': f"{data['class_accuracies'].get('men', 0.0):.4f}",
        'Women Accuracy': f"{data['class_accuracies'].get('women', 0.0):.4f}"
    })

summary_df = pd.DataFrame(summary_data)
print("\n以DataFrame格式的摘要:")
print(summary_df)

# 保存摘要為CSV
summary_df.to_csv(summary_csv_filename, index=False)
# Out:
# epochs_20_batch_8   1.0000    0.5500    0.5875    0.0002    3.5206    4.4459    0:03:44     0.5875    0.5750    0.6000
# epochs_20_batch_16  1.0000    0.5625    0.5875    0.0079    4.0833    4.1254    0:03:40     0.5875    0.5500    0.6250
# epochs_40_batch_8   1.0000    0.4750    0.6000    0.0000    5.8098    6.3142    0:07:06     0.6000    0.6750    0.5250
# epochs_40_batch_16  1.0000    0.5000    0.5625    0.0000    8.3240    5.2920    0:07:07     0.5625    0.5250    0.6000
# epochs_60_batch_8   1.0000    0.5500    0.5125    0.0000    7.0962    7.2941    0:10:42     0.5125    0.4750    0.5500
# epochs_60_batch_16  1.0000    0.5000    0.4875    0.0000    5.4468    5.6280    0:10:45     0.4875    0.5000    0.4750
#
# 以DataFrame格式的摘要:
#   Epochs Batch Size Train Accuracy Val Accuracy Test Accuracy Train Loss  \
# 0     20          8         1.0000       0.5500        0.5875     0.0002
# 1     20         16         1.0000       0.5625        0.5875     0.0079
# 2     40          8         1.0000       0.4750        0.6000     0.0000
# 3     40         16         1.0000       0.5000        0.5625     0.0000
# 4     60          8         1.0000       0.5500        0.5125     0.0000
# 5     60         16         1.0000       0.5000        0.4875     0.0000
#
#   Val Loss Test Loss Training Time Overall Accuracy Men Accuracy  \
# 0   3.5206    4.4459       0:03:44           0.5875       0.5750
# 1   4.0833    4.1254       0:03:40           0.5875       0.5500
# 2   5.8098    6.3142       0:07:06           0.6000       0.6750
# 3   8.3240    5.2920       0:07:07           0.5625       0.5250
# 4   7.0962    7.2941       0:10:42           0.5125       0.4750
# 5   5.4468    5.6280       0:10:45           0.4875       0.5000
#
#   Women Accuracy
# 0         0.6000
# 1         0.6250
# 2         0.5250
# 3         0.6000
# 4         0.5500
# 5         0.4750

# %%
import matplotlib.pyplot as plt

for key, data in results.items():
    plt.figure(figsize=(15, 5))  # 調整圖的大小以適應單個組合

    # 繪製訓練和驗證準確率
    plt.subplot(1, 2, 1)  # 使用 1 行 2 列的子圖
    epochs_count = len(data['history']['accuracy'])
    epochs_range = range(1, epochs_count + 1)
    plt.plot(epochs_range, data['history']['accuracy'], '-', label=f"{key} (train)")
    if 'val_accuracy' in data['history']:
        plt.plot(epochs_range, data['history']['val_accuracy'], '--', label=f"{key} (val)")
    plt.title(f'{key} - Train and Val Acc')
    plt.xlabel('Epochs')
    plt.ylabel('Acc')
    plt.legend(loc='lower right')
    plt.grid(True)

    # 繪製訓練和驗證損失
    plt.subplot(1, 2, 2)
    epochs_count = len(data['history']['loss'])
    epochs_range = range(1, epochs_count + 1)
    plt.plot(epochs_range, data['history']['loss'], '-', label=f"{key} (train)")
    if 'val_loss' in data['history']:
        plt.plot(epochs_range, data['history']['val_loss'], '--', label=f"{key} (val)")
    plt.title(f'{key} - Train and Val Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.grid(True)

    plt.tight_layout()
    filename = f'original_training_{key.replace(" ", "_")}.png'  # 創建包含參數組合名稱的文件名
    filepath = os.path.join(output_dir, filename)  # 組合路徑和檔名
    plt.savefig(filepath)
    print(f"參數組合 '{key}' 的訓練過程圖表已保存至: {filepath}")


print(f"\n所有參數組合的結果也已保存至: {csv_filename}, {detailed_csv_filename}, {summary_csv_filename}")
# Out:
# 參數組合 'epochs_20_batch_8' 的訓練過程圖表已保存至: C:/Users/user/Desktop/MLWORK/original_20_40_60\original_training_epochs_20_batch_8.png
# 參數組合 'epochs_20_batch_16' 的訓練過程圖表已保存至: C:/Users/user/Desktop/MLWORK/original_20_40_60\original_training_epochs_20_batch_16.png
# 參數組合 'epochs_40_batch_8' 的訓練過程圖表已保存至: C:/Users/user/Desktop/MLWORK/original_20_40_60\original_training_epochs_40_batch_8.png
# 參數組合 'epochs_40_batch_16' 的訓練過程圖表已保存至: C:/Users/user/Desktop/MLWORK/original_20_40_60\original_training_epochs_40_batch_16.png
# 參數組合 'epochs_60_batch_8' 的訓練過程圖表已保存至: C:/Users/user/Desktop/MLWORK/original_20_40_60\original_training_epochs_60_batch_8.png
# 參數組合 'epochs_60_batch_16' 的訓練過程圖表已保存至: C:/Users/user/Desktop/MLWORK/original_20_40_60\original_training_epochs_60_batch_16.png
#
# 所有參數組合的結果也已保存至: original_training_results.csv, C:/Users/user/Desktop/MLWORK/original_20_40_60\original_detailed_training_results.csv, C:/Users/user/Desktop/MLWORK/original_20_40_60\original_summary_results.csv

# %%
# 建立比較表格，以DataFrame方式顯示不同組合間的性能
comparison_table = pd.DataFrame({
    'Epochs_Batch': [key for key in results.keys()],
    'Test Acc': [results[key]['test_acc'] for key in results.keys()],
    'Train Acc': [results[key]['train_acc'] for key in results.keys()],
    'Val Acc': [results[key]['val_acc'] for key in results.keys()],
    'Test Loss': [results[key]['test_loss'] for key in results.keys()],
    'Train Loss': [results[key]['train_loss'] for key in results.keys()],
    'Val Loss': [results[key]['val_loss'] for key in results.keys()],
    'Training Time': [results[key]['formatted_time'] for key in results.keys()],
    'Overall Acc': [results[key]['overall_accuracy'] for key in results.keys()],
    'Men Acc': [results[key]['class_accuracies'].get('men', 0.0) for key in results.keys()],
    'Women Acc': [results[key]['class_accuracies'].get('women', 0.0) for key in results.keys()],
})
print("\n參數組合比較表:")
print(comparison_table.sort_values(by='Test Acc', ascending=False))
# Out:
# 參數組合比較表:
#          Epochs_Batch  Test Acc  Train Acc  Val Acc  Test Loss  Train Loss  \
# 2   epochs_40_batch_8    0.6000        1.0   0.4750   6.314208    0.000009
# 0   epochs_20_batch_8    0.5875        1.0   0.5500   4.445857    0.000199
# 1  epochs_20_batch_16    0.5875        1.0   0.5625   4.125448    0.007932
# 3  epochs_40_batch_16    0.5625        1.0   0.5000   5.291955    0.000026
# 4   epochs_60_batch_8    0.5125        1.0   0.5500   7.294063    0.000004
# 5  epochs_60_batch_16    0.4875        1.0   0.5000   5.627963    0.000029
#
#    Val Loss Training Time  Overall Acc  Men Acc  Women Acc
# 2  5.809771       0:07:06       0.6000    0.675      0.525
# 0  3.520607       0:03:44       0.5875    0.575      0.600
# 1  4.083258       0:03:40       0.5875    0.550      0.625
# 3  8.324030       0:07:07       0.5625    0.525      0.600
# 4  7.096155       0:10:42       0.5125    0.475      0.550
# 5  5.446756       0:10:45       0.4875    0.500      0.475
