# %%
import numpy as np 
import os
import tensorflow  as tf
from keras.models import Sequential
from keras.layers import Dense,Conv2D,Flatten,MaxPooling2D,UpSampling2D,InputLayer,Reshape

from keras.utils import image_dataset_from_directory
from keras.layers import Dropout,Activation,BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array
from tensorflow.keras.utils import array_to_img
import matplotlib.pyplot as plt

from keras.layers import LeakyReLU
from pathlib import Path
from skimage.io import imread
from skimage.transform import resize
from sklearn.utils import Bunch
import math
import pandas as pd
import datetime
import time
import csv
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import time
import datetime
import os
from PIL import Image
import sys

# %%
# 設定圖片大小和路徑
img_rows, img_cols = 256,256  # 縮小圖片尺寸以減少記憶體使用
train_data_dir = "C:/Users/user/Desktop/MLwork2/train"
test_data_dir = "C:/Users/user/Desktop/MLwork2/test"

# %%
# 準備測試不同的參數
epochs_list = [20,40,60]
batch_size_list = [8, 16]

# %%
# 對每種參數組合進行實驗
results = {}  # 用來存儲所有結果的字典
output_dir = 'C:/Users/user/Desktop/MLWORK/original'
csv_filename = 'original_training_results.csv'
detailed_csv_filename = os.path.join(output_dir, 'original_detailed_training_results.csv')
summary_csv_filename = os.path.join(output_dir, 'original_summary_results.csv')
plot_filename = os.path.join(output_dir, 'original_training_comparison.png')

os.makedirs(output_dir, exist_ok=True)

# 創建基本CSV文件並寫入標題
fieldnames = ['epochs', 'batch_size', 'train_acc', 'val_acc', 'test_acc', 
              'train_loss', 'val_loss', 'test_loss', 'training_time', 
              'overall_accuracy', 'men_accuracy', 'women_accuracy']

# 創建基本結果CSV
with open(csv_filename, 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()

# 創建詳細結果CSV (每個epoch的數據)
with open(detailed_csv_filename, 'w', newline='') as csvfile:
    detailed_fieldnames = ['combination', 'epoch', 'train_acc', 'val_acc', 'train_loss', 'val_loss']
    writer = csv.DictWriter(csvfile, fieldnames=detailed_fieldnames)
    writer.writeheader()

# %%
# 這邊只是輸出模型架構不然後面寫在迴圈裡會輸出很多次
reference_model = Sequential()

reference_model.add(Conv2D(32, (3,3), padding="same", input_shape=(img_rows,img_cols,3)))
reference_model.add(Activation("relu"))
reference_model.add(MaxPooling2D(pool_size=(3,3)))

reference_model.add(Conv2D(64, (3,3), padding="same"))
reference_model.add(Activation("relu"))

reference_model.add(Conv2D(64, (3,3), padding="same"))
reference_model.add(Activation("relu"))
reference_model.add(MaxPooling2D(pool_size=(2,2)))


reference_model.add(Conv2D(128, (3,3), padding="same"))
reference_model.add(Activation("relu"))


reference_model.add(Conv2D(128, (3,3), padding="same"))
reference_model.add(Activation("relu"))
reference_model.add(MaxPooling2D(pool_size=(2,2)))

reference_model.add(Flatten())
reference_model.add(Dense(1024, activation='relu'))
reference_model.add(Dense(1, activation='sigmoid'))

# 只顯示一次模型摘要
print("\n模型架構:")
reference_model.summary()
# Out:
# 模型架構:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 32)      896
#
#  activation (Activation)     (None, 256, 256, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 85, 85, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 85, 85, 64)        18496
#
#  activation_1 (Activation)   (None, 85, 85, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 85, 85, 64)        36928
#
#  activation_2 (Activation)   (None, 85, 85, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 42, 42, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 42, 42, 128)       73856
#
#  activation_3 (Activation)   (None, 42, 42, 128)       0
#
#  conv2d_4 (Conv2D)           (None, 42, 42, 128)       147584
#
#  activation_4 (Activation)   (None, 42, 42, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 21, 21, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 56448)             0
#
#  dense (Dense)               (None, 1024)              57803776
#
#  dense_1 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 58,082,561
# Trainable params: 58,082,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 對每種參數組合進行實驗
for epochs in epochs_list:
    for batch_size in batch_size_list:
        print(f"\n開始訓練 - epochs: {epochs}, batch_size: {batch_size}")
        
        # 資料增強和標準化
        train_datagen = ImageDataGenerator(
            validation_split=0.2,
            rescale=1./255,
        )
        
        validation_datagen = ImageDataGenerator(rescale=1./255)
        test_datagen = ImageDataGenerator(rescale=1./255)
        
        train_generator = train_datagen.flow_from_directory(
            train_data_dir,
            target_size=(img_rows, img_cols),
            batch_size=batch_size,
            class_mode='binary',
            shuffle=True,
            subset='training'
        )
        
        validation_generator = train_datagen.flow_from_directory(
            train_data_dir,
            batch_size=batch_size,
            target_size=(img_rows, img_cols),
            class_mode='binary',
            shuffle=True,
            subset='validation'
        )
        
        test_generator = test_datagen.flow_from_directory(
            test_data_dir,
            target_size=(img_rows, img_cols),
            batch_size=batch_size,
            class_mode='binary',
            shuffle=False
        )
        
        # 模型
        model = Sequential()
        
        model.add(Conv2D(32, (3,3), padding="same", input_shape=(img_rows,img_cols,3)))
        model.add(Activation("relu"))
        model.add(MaxPooling2D(pool_size=(3,3)))

        model.add(Conv2D(64, (3,3), padding="same"))
        model.add(Activation("relu"))

        model.add(Conv2D(64, (3,3), padding="same"))
        model.add(Activation("relu"))
        model.add(MaxPooling2D(pool_size=(2,2)))


        model.add(Conv2D(128, (3,3), padding="same"))
        model.add(Activation("relu"))


        model.add(Conv2D(128, (3,3), padding="same"))
        model.add(Activation("relu"))
        model.add(MaxPooling2D(pool_size=(2,2)))


        model.add(Flatten())
        model.add(Dense(1024, activation='relu'))
        model.add(Dense(1, activation='sigmoid'))
        
        model.compile(
            loss='binary_crossentropy',
            optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
            metrics=['accuracy']
        )
        
        # 記錄時間
        start_time = time.time()
        
        # 訓練模型
        history = model.fit(
            train_generator,
            steps_per_epoch=train_generator.samples // batch_size,
            epochs=epochs,
            validation_data=validation_generator,
            validation_steps=validation_generator.samples // batch_size
        )
        
        # 計算時間
        end_time = time.time()
        training_time = end_time - start_time
        formatted_time = str(datetime.timedelta(seconds=int(training_time)))
        
        # 在測試集上評估模型
        test_loss, test_acc = model.evaluate(
            test_generator,
            steps=test_generator.samples // batch_size + 1
        )
        
        # 計算每個類別的準確率
        y_pred = model.predict(test_generator, steps=test_generator.samples // batch_size + 1)
        y_pred_classes = (y_pred > 0.5).astype(int).flatten()
        
        # 獲取真實標籤
        test_generator.reset()
        y_true = test_generator.classes
        
         # 計算整體準確率（不分性別）
        overall_accuracy = np.mean(y_pred_classes == y_true)
        
        # 計算每個類別的準確率
        class_accuracies = {}
        for class_idx, class_name in enumerate(test_generator.class_indices.keys()):
            # 找出屬於該類別的樣本
            class_samples = np.where(y_true == class_idx)[0]
            if len(class_samples) > 0:
                # 計算該類別的準確率
                class_correct = np.sum(y_pred_classes[class_samples] == class_idx)
                class_accuracy = class_correct / len(class_samples)
                class_accuracies[class_name] = class_accuracy
            else:
                class_accuracies[class_name] = 0.0
        
        # 獲取最終訓練和驗證準確率/損失
        final_train_acc = history.history['accuracy'][-1]
        final_train_loss = history.history['loss'][-1]
        final_val_acc = history.history['val_accuracy'][-1] if 'val_accuracy' in history.history else None
        final_val_loss = history.history['val_loss'][-1] if 'val_loss' in history.history else None
        
        # 儲存結果
        key = f"epochs_{epochs}_batch_{batch_size}"
        results[key] = {
            'history': history.history,
            'test_acc': test_acc,
            'test_loss': test_loss,
            'training_time': training_time,
            'formatted_time': formatted_time,
            'overall_accuracy': overall_accuracy,
            'class_accuracies': class_accuracies,
            'train_acc': final_train_acc,
            'train_loss': final_train_loss,
            'val_acc': final_val_acc,
            'val_loss': final_val_loss
        }
        
        # 輸出當前實驗結果
        print(f"\n訓練完成 - epochs: {epochs}, batch_size: {batch_size}")
        print(f"訓練集準確率: {final_train_acc:.4f}, 損失: {final_train_loss:.4f}")
        print(f"驗證集準確率: {final_val_acc:.4f}, 損失: {final_val_loss:.4f}")
        print(f"測試集準確率: {test_acc:.4f}, 損失: {test_loss:.4f}")
        print(f"整體準確率(不分性別): {overall_accuracy:.4f}")
        print(f"訓練時間: {formatted_time}")
        print("各類別準確率:")
        for class_name, accuracy in class_accuracies.items():
            print(f"  {class_name}: {accuracy:.4f}")
            
        # 將結果寫入CSV
        with open(csv_filename, 'a', newline='') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            writer.writerow({
                'epochs': epochs,
                'batch_size': batch_size,
                'train_acc': f"{final_train_acc:.4f}",
                'val_acc': f"{final_val_acc:.4f}" if final_val_acc is not None else None,
                'test_acc': f"{test_acc:.4f}",
                'train_loss': f"{final_train_loss:.4f}",
                'val_loss': f"{final_val_loss:.4f}" if final_val_loss is not None else None,
                'test_loss': f"{test_loss:.4f}",
                'training_time': formatted_time,
                'overall_accuracy': f"{overall_accuracy:.4f}",
                'men_accuracy': f"{class_accuracies.get('men', 0.0):.4f}",
                'women_accuracy': f"{class_accuracies.get('women', 0.0):.4f}"
            })
            
        # 保存每個epoch的詳細資訊
        with open(detailed_csv_filename, 'a', newline='') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=detailed_fieldnames)
            for i in range(len(history.history['accuracy'])):
                writer.writerow({
                    'combination': key,
                    'epoch': i+1,
                    'train_acc': f"{history.history['accuracy'][i]:.4f}",
                    'val_acc': f"{history.history['val_accuracy'][i]:.4f}" if 'val_accuracy' in history.history else None,
                    'train_loss': f"{history.history['loss'][i]:.4f}",
                    'val_loss': f"{history.history['val_loss'][i]:.4f}" if 'val_loss' in history.history else None
                })
# Out:
# 開始訓練 - epochs: 20, batch_size: 8
# Found 176 images belonging to 2 classes.
# Found 44 images belonging to 2 classes.
# Found 80 images belonging to 2 classes.
# Epoch 1/20
# 22/22 [==============================] - 15s 504ms/step - loss: 0.7282 - accuracy: 0.5170 - val_loss: 0.6923 - val_accuracy: 0.5250
# Epoch 2/20
# 22/22 [==============================] - 10s 464ms/step - loss: 0.6927 - accuracy: 0.4886 - val_loss: 0.6929 - val_accuracy: 0.5500
# Epoch 3/20
# 22/22 [==============================] - 11s 481ms/step - loss: 0.6845 - accuracy: 0.5682 - val_loss: 0.6902 - val_accuracy: 0.5500
# Epoch 4/20
# 22/22 [==============================] - 11s 482ms/step - loss: 0.6657 - accuracy: 0.6193 - val_loss: 0.6791 - val_accuracy: 0.5750
# Epoch 5/20
# 22/22 [==============================] - 11s 493ms/step - loss: 0.6130 - accuracy: 0.6420 - val_loss: 0.7087 - val_accuracy: 0.4250
# Epoch 6/20
# 22/22 [==============================] - 11s 512ms/step - loss: 0.5300 - accuracy: 0.7500 - val_loss: 0.6806 - val_accuracy: 0.6000
# Epoch 7/20
# 22/22 [==============================] - 11s 468ms/step - loss: 0.4919 - accuracy: 0.7557 - val_loss: 1.0474 - val_accuracy: 0.5250
# Epoch 8/20
# 22/22 [==============================] - 11s 483ms/step - loss: 0.4301 - accuracy: 0.8125 - val_loss: 0.7870 - val_accuracy: 0.5750
# Epoch 9/20
# 22/22 [==============================] - 12s 526ms/step - loss: 0.2765 - accuracy: 0.8920 - val_loss: 0.9265 - val_accuracy: 0.5000
# Epoch 10/20
# 22/22 [==============================] - 11s 480ms/step - loss: 0.1812 - accuracy: 0.9432 - val_loss: 1.0928 - val_accuracy: 0.5250
# Epoch 11/20
# 22/22 [==============================] - 11s 481ms/step - loss: 0.1349 - accuracy: 0.9773 - val_loss: 1.1896 - val_accuracy: 0.4750
# Epoch 12/20
# 22/22 [==============================] - 11s 499ms/step - loss: 0.0993 - accuracy: 0.9773 - val_loss: 1.7633 - val_accuracy: 0.4500
# Epoch 13/20
# 22/22 [==============================] - 11s 493ms/step - loss: 0.0430 - accuracy: 0.9943 - val_loss: 2.1926 - val_accuracy: 0.4500
# Epoch 14/20
# 22/22 [==============================] - 11s 502ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 2.2405 - val_accuracy: 0.5000
# Epoch 15/20
# 22/22 [==============================] - 11s 487ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 2.4527 - val_accuracy: 0.5250
# Epoch 16/20
# 22/22 [==============================] - 11s 485ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 2.7257 - val_accuracy: 0.5000
# Epoch 17/20
# 22/22 [==============================] - 11s 514ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 3.0801 - val_accuracy: 0.4500
# Epoch 18/20
# 22/22 [==============================] - 11s 497ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 3.2108 - val_accuracy: 0.4500
# Epoch 19/20
# 22/22 [==============================] - 11s 497ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 3.1026 - val_accuracy: 0.5000
# Epoch 20/20
# 22/22 [==============================] - 12s 535ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 3.6506 - val_accuracy: 0.4250
# 10/11 [==========================>...] - ETA: 0s - loss: 2.1837 - accuracy: 0.5000WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# 11/11 [==============================] - 6s 519ms/step - loss: 2.1837 - accuracy: 0.5000
# 10/11 [==========================>...] - ETA: 0sWARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# 11/11 [==============================] - 5s 447ms/step
#
# 訓練完成 - epochs: 20, batch_size: 8
# 訓練集準確率: 1.0000, 損失: 0.0015
# 驗證集準確率: 0.4250, 損失: 3.6506
# 測試集準確率: 0.5000, 損失: 2.1837
# 整體準確率(不分性別): 0.5000
# 訓練時間: 0:03:43
# 各類別準確率:
#   men: 0.4750
#   women: 0.5250
#
# 開始訓練 - epochs: 20, batch_size: 16
# Found 176 images belonging to 2 classes.
# Found 44 images belonging to 2 classes.
# Found 80 images belonging to 2 classes.
# Epoch 1/20
# 11/11 [==============================] - 15s 1s/step - loss: 0.7194 - accuracy: 0.5057 - val_loss: 0.6936 - val_accuracy: 0.5625
# Epoch 2/20
# 11/11 [==============================] - 11s 976ms/step - loss: 0.6903 - accuracy: 0.5341 - val_loss: 0.6925 - val_accuracy: 0.5000
# Epoch 3/20
# 11/11 [==============================] - 11s 964ms/step - loss: 0.6806 - accuracy: 0.6080 - val_loss: 0.6934 - val_accuracy: 0.5312
# Epoch 4/20
# 11/11 [==============================] - 11s 1s/step - loss: 0.6616 - accuracy: 0.7784 - val_loss: 0.6879 - val_accuracy: 0.5938
# Epoch 5/20
# 11/11 [==============================] - 11s 996ms/step - loss: 0.6187 - accuracy: 0.7330 - val_loss: 0.6807 - val_accuracy: 0.5312
# Epoch 6/20
# 11/11 [==============================] - 11s 1s/step - loss: 0.5671 - accuracy: 0.7273 - val_loss: 0.6529 - val_accuracy: 0.6562
# Epoch 7/20
# 11/11 [==============================] - 11s 970ms/step - loss: 0.5038 - accuracy: 0.7841 - val_loss: 0.7539 - val_accuracy: 0.4688
# Epoch 8/20
# 11/11 [==============================] - 11s 998ms/step - loss: 0.4231 - accuracy: 0.8239 - val_loss: 0.7616 - val_accuracy: 0.5625
# Epoch 9/20
# 11/11 [==============================] - 11s 988ms/step - loss: 0.3595 - accuracy: 0.8466 - val_loss: 0.6986 - val_accuracy: 0.5625
# Epoch 10/20
# 11/11 [==============================] - 11s 1s/step - loss: 0.2902 - accuracy: 0.9034 - val_loss: 1.0164 - val_accuracy: 0.5312
# Epoch 11/20
# 11/11 [==============================] - 11s 963ms/step - loss: 0.2593 - accuracy: 0.9148 - val_loss: 0.9164 - val_accuracy: 0.5312
# Epoch 12/20
# 11/11 [==============================] - 11s 959ms/step - loss: 0.1878 - accuracy: 0.9602 - val_loss: 1.0301 - val_accuracy: 0.5625
# Epoch 13/20
# 11/11 [==============================] - 10s 944ms/step - loss: 0.1320 - accuracy: 0.9659 - val_loss: 1.2606 - val_accuracy: 0.5312
# Epoch 14/20
# 11/11 [==============================] - 10s 945ms/step - loss: 0.0992 - accuracy: 0.9602 - val_loss: 1.2443 - val_accuracy: 0.5312
# Epoch 15/20
# 11/11 [==============================] - 11s 948ms/step - loss: 0.0495 - accuracy: 1.0000 - val_loss: 1.6928 - val_accuracy: 0.4375
# Epoch 16/20
# 11/11 [==============================] - 10s 954ms/step - loss: 0.0281 - accuracy: 1.0000 - val_loss: 2.0085 - val_accuracy: 0.4688
# Epoch 17/20
# 11/11 [==============================] - 10s 950ms/step - loss: 0.0165 - accuracy: 1.0000 - val_loss: 1.7550 - val_accuracy: 0.6250
# Epoch 18/20
# 11/11 [==============================] - 11s 974ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 2.5215 - val_accuracy: 0.4375
# Epoch 19/20
# 11/11 [==============================] - 11s 960ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 2.0659 - val_accuracy: 0.5312
# Epoch 20/20
# 11/11 [==============================] - 11s 967ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 3.0790 - val_accuracy: 0.3750
# 5/6 [========================>.....] - ETA: 0s - loss: 2.0338 - accuracy: 0.5375WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# 6/6 [==============================] - 5s 759ms/step - loss: 2.0338 - accuracy: 0.5375
# 5/6 [========================>.....] - ETA: 0sWARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# 6/6 [==============================] - 5s 779ms/step
#
# 訓練完成 - epochs: 20, batch_size: 16
# 訓練集準確率: 1.0000, 損失: 0.0057
# 驗證集準確率: 0.3750, 損失: 3.0790
# 測試集準確率: 0.5375, 損失: 2.0338
# 整體準確率(不分性別): 0.5375
# 訓練時間: 0:03:39
# 各類別準確率:
#   men: 0.5500
#   women: 0.5250
#
# 開始訓練 - epochs: 40, batch_size: 8
# Found 176 images belonging to 2 classes.
# Found 44 images belonging to 2 classes.
# Found 80 images belonging to 2 classes.
# Epoch 1/40
# 22/22 [==============================] - 12s 504ms/step - loss: 0.7159 - accuracy: 0.4375 - val_loss: 0.6922 - val_accuracy: 0.5500
# Epoch 2/40
# 22/22 [==============================] - 10s 469ms/step - loss: 0.6838 - accuracy: 0.6648 - val_loss: 0.6893 - val_accuracy: 0.5250
# Epoch 3/40
# 22/22 [==============================] - 10s 462ms/step - loss: 0.6715 - accuracy: 0.5909 - val_loss: 0.6983 - val_accuracy: 0.5250
# Epoch 4/40
# 22/22 [==============================] - 10s 463ms/step - loss: 0.6447 - accuracy: 0.6250 - val_loss: 0.6913 - val_accuracy: 0.5750
# Epoch 5/40
# 22/22 [==============================] - 11s 475ms/step - loss: 0.6299 - accuracy: 0.6250 - val_loss: 0.6856 - val_accuracy: 0.5500
# Epoch 6/40
# 22/22 [==============================] - 11s 460ms/step - loss: 0.5390 - accuracy: 0.7330 - val_loss: 0.7234 - val_accuracy: 0.5500
# Epoch 7/40
# 22/22 [==============================] - 11s 467ms/step - loss: 0.4120 - accuracy: 0.8182 - val_loss: 0.9321 - val_accuracy: 0.4750
# Epoch 8/40
# 22/22 [==============================] - 11s 468ms/step - loss: 0.3400 - accuracy: 0.8807 - val_loss: 0.9743 - val_accuracy: 0.5000
# Epoch 9/40
# 22/22 [==============================] - 11s 490ms/step - loss: 0.2764 - accuracy: 0.8864 - val_loss: 1.0085 - val_accuracy: 0.4750
# Epoch 10/40
# 22/22 [==============================] - 11s 465ms/step - loss: 0.2185 - accuracy: 0.9148 - val_loss: 1.1101 - val_accuracy: 0.5500
# Epoch 11/40
# 22/22 [==============================] - 11s 473ms/step - loss: 0.0897 - accuracy: 0.9830 - val_loss: 1.3229 - val_accuracy: 0.5000
# Epoch 12/40
# 22/22 [==============================] - 11s 481ms/step - loss: 0.0565 - accuracy: 0.9886 - val_loss: 1.6023 - val_accuracy: 0.5250
# Epoch 13/40
# 22/22 [==============================] - 11s 487ms/step - loss: 0.0292 - accuracy: 1.0000 - val_loss: 1.8504 - val_accuracy: 0.5250
# Epoch 14/40
# 22/22 [==============================] - 11s 491ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 2.2806 - val_accuracy: 0.5500
# Epoch 15/40
# 22/22 [==============================] - 11s 488ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 2.4373 - val_accuracy: 0.5000
# Epoch 16/40
# 22/22 [==============================] - 11s 491ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 2.7286 - val_accuracy: 0.4750
# Epoch 17/40
# 22/22 [==============================] - 11s 480ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 2.7056 - val_accuracy: 0.4750
# Epoch 18/40
# 22/22 [==============================] - 11s 485ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 2.9281 - val_accuracy: 0.5000
# Epoch 19/40
# 22/22 [==============================] - 11s 481ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 2.8824 - val_accuracy: 0.5500
# Epoch 20/40
# 22/22 [==============================] - 11s 477ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 3.0543 - val_accuracy: 0.4750
# Epoch 21/40
# 22/22 [==============================] - 11s 491ms/step - loss: 9.7158e-04 - accuracy: 1.0000 - val_loss: 2.9548 - val_accuracy: 0.5000
# Epoch 22/40
# 22/22 [==============================] - 11s 483ms/step - loss: 8.3207e-04 - accuracy: 1.0000 - val_loss: 3.0352 - val_accuracy: 0.5250
# Epoch 23/40
# 22/22 [==============================] - 11s 482ms/step - loss: 6.9810e-04 - accuracy: 1.0000 - val_loss: 3.3281 - val_accuracy: 0.4750
# Epoch 24/40
# 22/22 [==============================] - 11s 474ms/step - loss: 5.9865e-04 - accuracy: 1.0000 - val_loss: 3.2824 - val_accuracy: 0.4750
# Epoch 25/40
# 22/22 [==============================] - 11s 482ms/step - loss: 5.4744e-04 - accuracy: 1.0000 - val_loss: 3.4056 - val_accuracy: 0.5250
# Epoch 26/40
# 22/22 [==============================] - 11s 472ms/step - loss: 4.6211e-04 - accuracy: 1.0000 - val_loss: 3.5319 - val_accuracy: 0.4750
# Epoch 27/40
# 22/22 [==============================] - 11s 475ms/step - loss: 4.1941e-04 - accuracy: 1.0000 - val_loss: 2.9595 - val_accuracy: 0.5250
# Epoch 28/40
# 22/22 [==============================] - 11s 485ms/step - loss: 3.5140e-04 - accuracy: 1.0000 - val_loss: 3.6521 - val_accuracy: 0.5000
# Epoch 29/40
# 22/22 [==============================] - 11s 470ms/step - loss: 3.2002e-04 - accuracy: 1.0000 - val_loss: 3.5722 - val_accuracy: 0.5000
# Epoch 30/40
# 22/22 [==============================] - 11s 486ms/step - loss: 2.8565e-04 - accuracy: 1.0000 - val_loss: 3.3372 - val_accuracy: 0.5250
# Epoch 31/40
# 22/22 [==============================] - 11s 487ms/step - loss: 2.5223e-04 - accuracy: 1.0000 - val_loss: 3.5501 - val_accuracy: 0.5000
# Epoch 32/40
# 22/22 [==============================] - 11s 475ms/step - loss: 2.2648e-04 - accuracy: 1.0000 - val_loss: 3.6932 - val_accuracy: 0.5000
# Epoch 33/40
# 22/22 [==============================] - 11s 476ms/step - loss: 2.0394e-04 - accuracy: 1.0000 - val_loss: 3.9314 - val_accuracy: 0.5000
# Epoch 34/40
# 22/22 [==============================] - 11s 475ms/step - loss: 1.8398e-04 - accuracy: 1.0000 - val_loss: 3.6478 - val_accuracy: 0.5250
# Epoch 35/40
# 22/22 [==============================] - 10s 468ms/step - loss: 1.6705e-04 - accuracy: 1.0000 - val_loss: 3.8240 - val_accuracy: 0.4750
# Epoch 36/40
# 22/22 [==============================] - 11s 482ms/step - loss: 1.5549e-04 - accuracy: 1.0000 - val_loss: 4.1591 - val_accuracy: 0.4500
# Epoch 37/40
# 22/22 [==============================] - 11s 489ms/step - loss: 1.4294e-04 - accuracy: 1.0000 - val_loss: 3.9381 - val_accuracy: 0.4750
# Epoch 38/40
# 22/22 [==============================] - 11s 490ms/step - loss: 1.3342e-04 - accuracy: 1.0000 - val_loss: 3.7756 - val_accuracy: 0.5250
# Epoch 39/40
# 22/22 [==============================] - 11s 482ms/step - loss: 1.1886e-04 - accuracy: 1.0000 - val_loss: 3.6879 - val_accuracy: 0.5250
# Epoch 40/40
# 22/22 [==============================] - 11s 479ms/step - loss: 1.1016e-04 - accuracy: 1.0000 - val_loss: 3.9149 - val_accuracy: 0.5250
# 10/11 [==========================>...] - ETA: 0s - loss: 2.7745 - accuracy: 0.6000WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# 11/11 [==============================] - 5s 409ms/step - loss: 2.7745 - accuracy: 0.6000
# 10/11 [==========================>...] - ETA: 0sWARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# 11/11 [==============================] - 5s 408ms/step
#
# 訓練完成 - epochs: 40, batch_size: 8
# 訓練集準確率: 1.0000, 損失: 0.0001
# 驗證集準確率: 0.5250, 損失: 3.9149
# 測試集準確率: 0.6000, 損失: 2.7745
# 整體準確率(不分性別): 0.6000
# 訓練時間: 0:07:10
# 各類別準確率:
#   men: 0.5750
#   women: 0.6250
#
# 開始訓練 - epochs: 40, batch_size: 16
# Found 176 images belonging to 2 classes.
# Found 44 images belonging to 2 classes.
# Found 80 images belonging to 2 classes.
# Epoch 1/40
# 11/11 [==============================] - 12s 1s/step - loss: 0.7118 - accuracy: 0.4943 - val_loss: 0.7061 - val_accuracy: 0.4688
# Epoch 2/40
# 11/11 [==============================] - 11s 974ms/step - loss: 0.6960 - accuracy: 0.4375 - val_loss: 0.6918 - val_accuracy: 0.5000
# Epoch 3/40
# 11/11 [==============================] - 11s 975ms/step - loss: 0.6889 - accuracy: 0.6023 - val_loss: 0.6926 - val_accuracy: 0.5000
# Epoch 4/40
# 11/11 [==============================] - 11s 973ms/step - loss: 0.6821 - accuracy: 0.7330 - val_loss: 0.6870 - val_accuracy: 0.6250
# Epoch 5/40
# 11/11 [==============================] - 11s 971ms/step - loss: 0.6643 - accuracy: 0.6761 - val_loss: 0.6837 - val_accuracy: 0.5312
# Epoch 6/40
# 11/11 [==============================] - 11s 987ms/step - loss: 0.6289 - accuracy: 0.7557 - val_loss: 0.6808 - val_accuracy: 0.4375
# Epoch 7/40
# 11/11 [==============================] - 11s 917ms/step - loss: 0.5651 - accuracy: 0.7386 - val_loss: 0.6733 - val_accuracy: 0.6250
# Epoch 8/40
# 11/11 [==============================] - 11s 986ms/step - loss: 0.4843 - accuracy: 0.7727 - val_loss: 0.6361 - val_accuracy: 0.6875
# Epoch 9/40
# 11/11 [==============================] - 11s 980ms/step - loss: 0.4279 - accuracy: 0.8068 - val_loss: 0.8425 - val_accuracy: 0.4375
# Epoch 10/40
# 11/11 [==============================] - 11s 969ms/step - loss: 0.3528 - accuracy: 0.8523 - val_loss: 0.8033 - val_accuracy: 0.5312
# Epoch 11/40
# 11/11 [==============================] - 11s 961ms/step - loss: 0.2771 - accuracy: 0.9091 - val_loss: 0.8369 - val_accuracy: 0.5625
# Epoch 12/40
# 11/11 [==============================] - 11s 981ms/step - loss: 0.1810 - accuracy: 0.9659 - val_loss: 1.2436 - val_accuracy: 0.4375
# Epoch 13/40
# 11/11 [==============================] - 11s 948ms/step - loss: 0.1294 - accuracy: 0.9830 - val_loss: 1.3863 - val_accuracy: 0.4375
# Epoch 14/40
# 11/11 [==============================] - 11s 1s/step - loss: 0.0925 - accuracy: 0.9886 - val_loss: 1.7267 - val_accuracy: 0.4688
# Epoch 15/40
# 11/11 [==============================] - 11s 987ms/step - loss: 0.0702 - accuracy: 0.9943 - val_loss: 1.9470 - val_accuracy: 0.5000
# Epoch 16/40
# 11/11 [==============================] - 11s 966ms/step - loss: 0.0526 - accuracy: 0.9943 - val_loss: 1.8312 - val_accuracy: 0.5625
# Epoch 17/40
# 11/11 [==============================] - 11s 936ms/step - loss: 0.0249 - accuracy: 1.0000 - val_loss: 2.0072 - val_accuracy: 0.5000
# Epoch 18/40
# 11/11 [==============================] - 11s 987ms/step - loss: 0.0218 - accuracy: 1.0000 - val_loss: 2.7696 - val_accuracy: 0.4375
# Epoch 19/40
# 11/11 [==============================] - 11s 968ms/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 2.0876 - val_accuracy: 0.4688
# Epoch 20/40
# 11/11 [==============================] - 11s 985ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 3.0292 - val_accuracy: 0.3750
# Epoch 21/40
# 11/11 [==============================] - 11s 970ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 3.2397 - val_accuracy: 0.4375
# Epoch 22/40
# 11/11 [==============================] - 11s 960ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 3.2063 - val_accuracy: 0.4375
# Epoch 23/40
# 11/11 [==============================] - 11s 979ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 3.4141 - val_accuracy: 0.4375
# Epoch 24/40
# 11/11 [==============================] - 11s 973ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 2.8447 - val_accuracy: 0.5312
# Epoch 25/40
# 11/11 [==============================] - 11s 967ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 2.5645 - val_accuracy: 0.5312
# Epoch 26/40
# 11/11 [==============================] - 11s 998ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 3.6119 - val_accuracy: 0.4375
# Epoch 27/40
# 11/11 [==============================] - 11s 996ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 3.1045 - val_accuracy: 0.5000
# Epoch 28/40
# 11/11 [==============================] - 11s 955ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 3.6160 - val_accuracy: 0.5000
# Epoch 29/40
# 11/11 [==============================] - 11s 1s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 3.6485 - val_accuracy: 0.4688
# Epoch 30/40
# 11/11 [==============================] - 11s 984ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 3.7297 - val_accuracy: 0.5000
# Epoch 31/40
# 11/11 [==============================] - 11s 963ms/step - loss: 8.8426e-04 - accuracy: 1.0000 - val_loss: 3.2989 - val_accuracy: 0.5312
# Epoch 32/40
# 11/11 [==============================] - 11s 989ms/step - loss: 8.1181e-04 - accuracy: 1.0000 - val_loss: 3.1346 - val_accuracy: 0.5000
# Epoch 33/40
# 11/11 [==============================] - 11s 972ms/step - loss: 7.3335e-04 - accuracy: 1.0000 - val_loss: 2.6585 - val_accuracy: 0.5312
# Epoch 34/40
# 11/11 [==============================] - 11s 947ms/step - loss: 6.6294e-04 - accuracy: 1.0000 - val_loss: 4.4313 - val_accuracy: 0.4688
# Epoch 35/40
# 11/11 [==============================] - 11s 963ms/step - loss: 6.1264e-04 - accuracy: 1.0000 - val_loss: 3.6684 - val_accuracy: 0.4062
# Epoch 36/40
# 11/11 [==============================] - 11s 959ms/step - loss: 5.6472e-04 - accuracy: 1.0000 - val_loss: 3.3580 - val_accuracy: 0.5000
# Epoch 37/40
# 11/11 [==============================] - 11s 989ms/step - loss: 5.2520e-04 - accuracy: 1.0000 - val_loss: 3.8555 - val_accuracy: 0.5312
# Epoch 38/40
# 11/11 [==============================] - 11s 981ms/step - loss: 5.0514e-04 - accuracy: 1.0000 - val_loss: 3.6998 - val_accuracy: 0.5000
# Epoch 39/40
# 11/11 [==============================] - 11s 1s/step - loss: 4.5818e-04 - accuracy: 1.0000 - val_loss: 3.5778 - val_accuracy: 0.5000
# Epoch 40/40
# 11/11 [==============================] - 11s 976ms/step - loss: 4.2394e-04 - accuracy: 1.0000 - val_loss: 3.5253 - val_accuracy: 0.5000
# 5/6 [========================>.....] - ETA: 0s - loss: 3.0345 - accuracy: 0.5500WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# 6/6 [==============================] - 5s 765ms/step - loss: 3.0345 - accuracy: 0.5500
# 5/6 [========================>.....] - ETA: 0sWARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# 6/6 [==============================] - 5s 779ms/step
#
# 訓練完成 - epochs: 40, batch_size: 16
# 訓練集準確率: 1.0000, 損失: 0.0004
# 驗證集準確率: 0.5000, 損失: 3.5253
# 測試集準確率: 0.5500, 損失: 3.0345
# 整體準確率(不分性別): 0.5500
# 訓練時間: 0:07:15
# 各類別準確率:
#   men: 0.5500
#   women: 0.5500
#
# 開始訓練 - epochs: 60, batch_size: 8
# Found 176 images belonging to 2 classes.
# Found 44 images belonging to 2 classes.
# Found 80 images belonging to 2 classes.
# Epoch 1/60
# 22/22 [==============================] - 12s 499ms/step - loss: 0.7298 - accuracy: 0.4432 - val_loss: 0.6925 - val_accuracy: 0.5250
# Epoch 2/60
# 22/22 [==============================] - 11s 487ms/step - loss: 0.6908 - accuracy: 0.5114 - val_loss: 0.6932 - val_accuracy: 0.5250
# Epoch 3/60
# 22/22 [==============================] - 11s 473ms/step - loss: 0.6768 - accuracy: 0.6364 - val_loss: 0.6861 - val_accuracy: 0.5500
# Epoch 4/60
# 22/22 [==============================] - 11s 490ms/step - loss: 0.6392 - accuracy: 0.6932 - val_loss: 0.6926 - val_accuracy: 0.5000
# Epoch 5/60
# 22/22 [==============================] - 11s 481ms/step - loss: 0.5544 - accuracy: 0.7727 - val_loss: 0.7107 - val_accuracy: 0.4500
# Epoch 6/60
# 22/22 [==============================] - 11s 478ms/step - loss: 0.4749 - accuracy: 0.7557 - val_loss: 0.7175 - val_accuracy: 0.5500
# Epoch 7/60
# 22/22 [==============================] - 11s 481ms/step - loss: 0.3515 - accuracy: 0.8693 - val_loss: 0.8030 - val_accuracy: 0.6000
# Epoch 8/60
# 22/22 [==============================] - 11s 488ms/step - loss: 0.2663 - accuracy: 0.8693 - val_loss: 0.7285 - val_accuracy: 0.6000
# Epoch 9/60
# 22/22 [==============================] - 11s 488ms/step - loss: 0.2326 - accuracy: 0.9148 - val_loss: 1.0707 - val_accuracy: 0.5250
# Epoch 10/60
# 22/22 [==============================] - 11s 473ms/step - loss: 0.1062 - accuracy: 0.9716 - val_loss: 1.3989 - val_accuracy: 0.4750
# Epoch 11/60
# 22/22 [==============================] - 11s 480ms/step - loss: 0.0440 - accuracy: 1.0000 - val_loss: 1.8076 - val_accuracy: 0.5250
# Epoch 12/60
# 22/22 [==============================] - 11s 480ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 2.3415 - val_accuracy: 0.4750
# Epoch 13/60
# 22/22 [==============================] - 11s 475ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 2.2370 - val_accuracy: 0.5500
# Epoch 14/60
# 22/22 [==============================] - 11s 496ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 2.1465 - val_accuracy: 0.5500
# Epoch 15/60
# 22/22 [==============================] - 11s 501ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 2.6811 - val_accuracy: 0.5250
# Epoch 16/60
# 22/22 [==============================] - 13s 596ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 2.5478 - val_accuracy: 0.5500
# Epoch 17/60
# 22/22 [==============================] - 11s 482ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 2.4304 - val_accuracy: 0.5250
# Epoch 18/60
# 22/22 [==============================] - 11s 492ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 2.7890 - val_accuracy: 0.5250
# Epoch 19/60
# 22/22 [==============================] - 11s 496ms/step - loss: 9.8788e-04 - accuracy: 1.0000 - val_loss: 3.1533 - val_accuracy: 0.4750
# Epoch 20/60
# 22/22 [==============================] - 11s 493ms/step - loss: 8.3201e-04 - accuracy: 1.0000 - val_loss: 2.9381 - val_accuracy: 0.5250
# Epoch 21/60
# 22/22 [==============================] - 11s 477ms/step - loss: 7.2438e-04 - accuracy: 1.0000 - val_loss: 3.2745 - val_accuracy: 0.4750
# Epoch 22/60
# 22/22 [==============================] - 11s 485ms/step - loss: 6.1134e-04 - accuracy: 1.0000 - val_loss: 3.3628 - val_accuracy: 0.4750
# Epoch 23/60
# 22/22 [==============================] - 11s 479ms/step - loss: 5.3316e-04 - accuracy: 1.0000 - val_loss: 3.1408 - val_accuracy: 0.5000
# Epoch 24/60
# 22/22 [==============================] - 11s 479ms/step - loss: 4.7470e-04 - accuracy: 1.0000 - val_loss: 3.4164 - val_accuracy: 0.5000
# Epoch 25/60
# 22/22 [==============================] - 11s 505ms/step - loss: 4.2562e-04 - accuracy: 1.0000 - val_loss: 3.4142 - val_accuracy: 0.5000
# Epoch 26/60
# 22/22 [==============================] - 11s 470ms/step - loss: 3.8713e-04 - accuracy: 1.0000 - val_loss: 3.1049 - val_accuracy: 0.5250
# Epoch 27/60
# 22/22 [==============================] - 11s 481ms/step - loss: 3.5115e-04 - accuracy: 1.0000 - val_loss: 3.3109 - val_accuracy: 0.5000
# Epoch 28/60
# 22/22 [==============================] - 11s 490ms/step - loss: 3.2953e-04 - accuracy: 1.0000 - val_loss: 3.1762 - val_accuracy: 0.5250
# Epoch 29/60
# 22/22 [==============================] - 11s 471ms/step - loss: 2.9103e-04 - accuracy: 1.0000 - val_loss: 3.3778 - val_accuracy: 0.5000
# Epoch 30/60
# 22/22 [==============================] - 11s 480ms/step - loss: 2.6328e-04 - accuracy: 1.0000 - val_loss: 3.2651 - val_accuracy: 0.5250
# Epoch 31/60
# 22/22 [==============================] - 11s 467ms/step - loss: 2.3938e-04 - accuracy: 1.0000 - val_loss: 3.7733 - val_accuracy: 0.4750
# Epoch 32/60
# 22/22 [==============================] - 11s 480ms/step - loss: 2.2329e-04 - accuracy: 1.0000 - val_loss: 3.1126 - val_accuracy: 0.5250
# Epoch 33/60
# 22/22 [==============================] - 11s 473ms/step - loss: 2.0726e-04 - accuracy: 1.0000 - val_loss: 3.6963 - val_accuracy: 0.4750
# Epoch 34/60
# 22/22 [==============================] - 11s 481ms/step - loss: 1.9228e-04 - accuracy: 1.0000 - val_loss: 3.7268 - val_accuracy: 0.4750
# Epoch 35/60
# 22/22 [==============================] - 11s 471ms/step - loss: 1.7940e-04 - accuracy: 1.0000 - val_loss: 3.8051 - val_accuracy: 0.4750
# Epoch 36/60
# 22/22 [==============================] - 11s 473ms/step - loss: 1.6217e-04 - accuracy: 1.0000 - val_loss: 3.5655 - val_accuracy: 0.5000
# Epoch 37/60
# 22/22 [==============================] - 11s 472ms/step - loss: 1.5079e-04 - accuracy: 1.0000 - val_loss: 3.5655 - val_accuracy: 0.5250
# Epoch 38/60
# 22/22 [==============================] - 11s 465ms/step - loss: 1.4236e-04 - accuracy: 1.0000 - val_loss: 4.0195 - val_accuracy: 0.4750
# Epoch 39/60
# 22/22 [==============================] - 11s 478ms/step - loss: 1.3006e-04 - accuracy: 1.0000 - val_loss: 4.0747 - val_accuracy: 0.4750
# Epoch 40/60
# 22/22 [==============================] - 11s 474ms/step - loss: 1.2201e-04 - accuracy: 1.0000 - val_loss: 3.7581 - val_accuracy: 0.4750
# Epoch 41/60
# 22/22 [==============================] - 11s 471ms/step - loss: 1.1521e-04 - accuracy: 1.0000 - val_loss: 3.8834 - val_accuracy: 0.4750
# Epoch 42/60
# 22/22 [==============================] - 10s 464ms/step - loss: 1.0736e-04 - accuracy: 1.0000 - val_loss: 3.8155 - val_accuracy: 0.5000
# Epoch 43/60
# 22/22 [==============================] - 11s 468ms/step - loss: 1.0155e-04 - accuracy: 1.0000 - val_loss: 3.7798 - val_accuracy: 0.5000
# Epoch 44/60
# 22/22 [==============================] - 11s 474ms/step - loss: 9.5267e-05 - accuracy: 1.0000 - val_loss: 3.8173 - val_accuracy: 0.5250
# Epoch 45/60
# 22/22 [==============================] - 11s 479ms/step - loss: 9.0633e-05 - accuracy: 1.0000 - val_loss: 3.7902 - val_accuracy: 0.5000
# Epoch 46/60
# 22/22 [==============================] - 11s 476ms/step - loss: 8.8351e-05 - accuracy: 1.0000 - val_loss: 3.4516 - val_accuracy: 0.5500
# Epoch 47/60
# 22/22 [==============================] - 11s 476ms/step - loss: 8.2754e-05 - accuracy: 1.0000 - val_loss: 3.9861 - val_accuracy: 0.4750
# Epoch 48/60
# 22/22 [==============================] - 11s 470ms/step - loss: 7.7619e-05 - accuracy: 1.0000 - val_loss: 3.9464 - val_accuracy: 0.5000
# Epoch 49/60
# 22/22 [==============================] - 11s 477ms/step - loss: 7.4129e-05 - accuracy: 1.0000 - val_loss: 3.8234 - val_accuracy: 0.5250
# Epoch 50/60
# 22/22 [==============================] - 11s 482ms/step - loss: 7.7371e-05 - accuracy: 1.0000 - val_loss: 3.9543 - val_accuracy: 0.4750
# Epoch 51/60
# 22/22 [==============================] - 11s 473ms/step - loss: 6.7944e-05 - accuracy: 1.0000 - val_loss: 4.0522 - val_accuracy: 0.5000
# Epoch 52/60
# 22/22 [==============================] - 11s 469ms/step - loss: 6.3833e-05 - accuracy: 1.0000 - val_loss: 3.9480 - val_accuracy: 0.5250
# Epoch 53/60
# 22/22 [==============================] - 11s 481ms/step - loss: 5.9588e-05 - accuracy: 1.0000 - val_loss: 4.2768 - val_accuracy: 0.5000
# Epoch 54/60
# 22/22 [==============================] - 11s 470ms/step - loss: 5.7286e-05 - accuracy: 1.0000 - val_loss: 3.7328 - val_accuracy: 0.5500
# Epoch 55/60
# 22/22 [==============================] - 11s 474ms/step - loss: 5.5520e-05 - accuracy: 1.0000 - val_loss: 4.0849 - val_accuracy: 0.5000
# Epoch 56/60
# 22/22 [==============================] - 11s 477ms/step - loss: 5.2871e-05 - accuracy: 1.0000 - val_loss: 4.2294 - val_accuracy: 0.5000
# Epoch 57/60
# 22/22 [==============================] - 11s 481ms/step - loss: 5.0608e-05 - accuracy: 1.0000 - val_loss: 3.4943 - val_accuracy: 0.5500
# Epoch 58/60
# 22/22 [==============================] - 11s 481ms/step - loss: 4.8873e-05 - accuracy: 1.0000 - val_loss: 4.1271 - val_accuracy: 0.4750
# Epoch 59/60
# 22/22 [==============================] - 11s 482ms/step - loss: 4.5786e-05 - accuracy: 1.0000 - val_loss: 3.5856 - val_accuracy: 0.5250
# Epoch 60/60
# 22/22 [==============================] - 11s 466ms/step - loss: 4.4006e-05 - accuracy: 1.0000 - val_loss: 4.1798 - val_accuracy: 0.5000
# 10/11 [==========================>...] - ETA: 0s - loss: 2.9921 - accuracy: 0.6125WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# 11/11 [==============================] - 5s 402ms/step - loss: 2.9921 - accuracy: 0.6125
# 10/11 [==========================>...] - ETA: 0sWARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
# 11/11 [==============================] - 5s 407ms/step
#
# 訓練完成 - epochs: 60, batch_size: 8
# 訓練集準確率: 1.0000, 損失: 0.0000
# 驗證集準確率: 0.5000, 損失: 4.1798
# 測試集準確率: 0.6125, 損失: 2.9921
# 整體準確率(不分性別): 0.6125
# 訓練時間: 0:10:47
# 各類別準確率:
#   men: 0.6250
#   women: 0.6000
#
# 開始訓練 - epochs: 60, batch_size: 16
# Found 176 images belonging to 2 classes.
# Found 44 images belonging to 2 classes.
# Found 80 images belonging to 2 classes.
# Epoch 1/60
# 11/11 [==============================] - 12s 1s/step - loss: 0.7158 - accuracy: 0.5398 - val_loss: 0.7123 - val_accuracy: 0.4688
# Epoch 2/60
# 11/11 [==============================] - 10s 915ms/step - loss: 0.6970 - accuracy: 0.4602 - val_loss: 0.6921 - val_accuracy: 0.5312
# Epoch 3/60
# 11/11 [==============================] - 10s 937ms/step - loss: 0.6931 - accuracy: 0.4659 - val_loss: 0.6937 - val_accuracy: 0.5312
# Epoch 4/60
# 11/11 [==============================] - 10s 929ms/step - loss: 0.6874 - accuracy: 0.6705 - val_loss: 0.6971 - val_accuracy: 0.4062
# Epoch 5/60
# 11/11 [==============================] - 11s 947ms/step - loss: 0.6839 - accuracy: 0.6136 - val_loss: 0.6864 - val_accuracy: 0.5625
# Epoch 6/60
# 11/11 [==============================] - 10s 954ms/step - loss: 0.6629 - accuracy: 0.7045 - val_loss: 0.6914 - val_accuracy: 0.5312
# Epoch 7/60
# 11/11 [==============================] - 11s 981ms/step - loss: 0.6371 - accuracy: 0.6932 - val_loss: 0.7102 - val_accuracy: 0.5000
# Epoch 8/60
# 11/11 [==============================] - 11s 927ms/step - loss: 0.6027 - accuracy: 0.6705 - val_loss: 0.6773 - val_accuracy: 0.6250
# Epoch 9/60
# 11/11 [==============================] - 10s 947ms/step - loss: 0.5293 - accuracy: 0.7898 - val_loss: 0.8139 - val_accuracy: 0.5625
# Epoch 10/60
# 11/11 [==============================] - 11s 958ms/step - loss: 0.5092 - accuracy: 0.7443 - val_loss: 0.7067 - val_accuracy: 0.6250
# Epoch 11/60
# 11/11 [==============================] - 11s 954ms/step - loss: 0.4508 - accuracy: 0.7955 - val_loss: 0.8079 - val_accuracy: 0.5000
# Epoch 12/60
# 11/11 [==============================] - 10s 914ms/step - loss: 0.3832 - accuracy: 0.8864 - val_loss: 0.7866 - val_accuracy: 0.4062
# Epoch 13/60
# 11/11 [==============================] - 10s 943ms/step - loss: 0.2971 - accuracy: 0.9034 - val_loss: 0.9156 - val_accuracy: 0.5000
# Epoch 14/60
# 11/11 [==============================] - 11s 955ms/step - loss: 0.1911 - accuracy: 0.9545 - val_loss: 1.1622 - val_accuracy: 0.3750
# Epoch 15/60
# 11/11 [==============================] - 11s 1s/step - loss: 0.1388 - accuracy: 0.9773 - val_loss: 1.3851 - val_accuracy: 0.4062
# Epoch 16/60
# 11/11 [==============================] - 11s 949ms/step - loss: 0.1298 - accuracy: 0.9545 - val_loss: 1.4982 - val_accuracy: 0.4688
# Epoch 17/60
# 11/11 [==============================] - 11s 938ms/step - loss: 0.0928 - accuracy: 0.9773 - val_loss: 1.4818 - val_accuracy: 0.4688
# Epoch 18/60
# 11/11 [==============================] - 10s 921ms/step - loss: 0.0575 - accuracy: 0.9943 - val_loss: 1.4754 - val_accuracy: 0.4375
# Epoch 19/60
# 11/11 [==============================] - 11s 958ms/step - loss: 0.0680 - accuracy: 1.0000 - val_loss: 1.6307 - val_accuracy: 0.5625
# Epoch 20/60
# 11/11 [==============================] - 11s 926ms/step - loss: 0.0446 - accuracy: 1.0000 - val_loss: 1.8237 - val_accuracy: 0.4375
# Epoch 21/60
# 11/11 [==============================] - 11s 936ms/step - loss: 0.0292 - accuracy: 1.0000 - val_loss: 1.9230 - val_accuracy: 0.4688
# Epoch 22/60
# 11/11 [==============================] - 10s 970ms/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 2.2719 - val_accuracy: 0.5000
# Epoch 23/60
# 11/11 [==============================] - 11s 958ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 2.2811 - val_accuracy: 0.5000
# Epoch 24/60
# 11/11 [==============================] - 10s 952ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 2.2941 - val_accuracy: 0.4375
# Epoch 25/60
# 11/11 [==============================] - 11s 945ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 2.3723 - val_accuracy: 0.4375
# Epoch 26/60
# 11/11 [==============================] - 10s 930ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 2.6942 - val_accuracy: 0.4375
# Epoch 27/60
# 11/11 [==============================] - 11s 965ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 2.2987 - val_accuracy: 0.4688
# Epoch 28/60
# 11/11 [==============================] - 11s 983ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 2.3565 - val_accuracy: 0.5000
# Epoch 29/60
# 11/11 [==============================] - 11s 970ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 2.9188 - val_accuracy: 0.5000
# Epoch 30/60
# 11/11 [==============================] - 10s 939ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 3.2441 - val_accuracy: 0.4375
# Epoch 31/60
# 11/11 [==============================] - 11s 958ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 2.5156 - val_accuracy: 0.5000
# Epoch 32/60
# 11/11 [==============================] - 11s 971ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 2.9598 - val_accuracy: 0.4688
# Epoch 33/60
# 11/11 [==============================] - 10s 918ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 3.1326 - val_accuracy: 0.4688
# Epoch 34/60
# 11/11 [==============================] - 11s 974ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 2.8096 - val_accuracy: 0.5000
# Epoch 35/60
# 11/11 [==============================] - 10s 927ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 2.6705 - val_accuracy: 0.5000
# Epoch 36/60
# 11/11 [==============================] - 11s 936ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 3.2557 - val_accuracy: 0.4375
# Epoch 37/60
# 11/11 [==============================] - 11s 954ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 3.2411 - val_accuracy: 0.5000
# Epoch 38/60
# 11/11 [==============================] - 11s 926ms/step - loss: 9.1610e-04 - accuracy: 1.0000 - val_loss: 3.0600 - val_accuracy: 0.5000
# Epoch 39/60
# 11/11 [==============================] - 11s 947ms/step - loss: 8.4679e-04 - accuracy: 1.0000 - val_loss: 3.5795 - val_accuracy: 0.4375
# Epoch 40/60
# 11/11 [==============================] - 11s 971ms/step - loss: 7.9749e-04 - accuracy: 1.0000 - val_loss: 2.7592 - val_accuracy: 0.4375
# Epoch 41/60
# 11/11 [==============================] - 11s 940ms/step - loss: 7.3079e-04 - accuracy: 1.0000 - val_loss: 2.8144 - val_accuracy: 0.4688
# Epoch 42/60
# 11/11 [==============================] - 10s 923ms/step - loss: 6.8434e-04 - accuracy: 1.0000 - val_loss: 2.9539 - val_accuracy: 0.5312
# Epoch 43/60
# 11/11 [==============================] - 11s 953ms/step - loss: 6.5889e-04 - accuracy: 1.0000 - val_loss: 3.0966 - val_accuracy: 0.4375
# Epoch 44/60
# 11/11 [==============================] - 11s 941ms/step - loss: 5.8969e-04 - accuracy: 1.0000 - val_loss: 3.0617 - val_accuracy: 0.4375
# Epoch 45/60
# 11/11 [==============================] - 11s 968ms/step - loss: 5.6331e-04 - accuracy: 1.0000 - val_loss: 3.7989 - val_accuracy: 0.4062
# Epoch 46/60
# 11/11 [==============================] - 11s 971ms/step - loss: 5.3990e-04 - accuracy: 1.0000 - val_loss: 3.6368 - val_accuracy: 0.4062
# Epoch 47/60
# 11/11 [==============================] - 11s 974ms/step - loss: 4.9599e-04 - accuracy: 1.0000 - val_loss: 2.9895 - val_accuracy: 0.5312
# Epoch 48/60
# 11/11 [==============================] - 10s 923ms/step - loss: 4.6861e-04 - accuracy: 1.0000 - val_loss: 3.8571 - val_accuracy: 0.4375
# Epoch 49/60
# 11/11 [==============================] - 11s 961ms/step - loss: 4.4853e-04 - accuracy: 1.0000 - val_loss: 3.3375 - val_accuracy: 0.4688
# Epoch 50/60
# 11/11 [==============================] - 11s 991ms/step - loss: 4.3962e-04 - accuracy: 1.0000 - val_loss: 3.5484 - val_accuracy: 0.4688
# Epoch 51/60
# 11/11 [==============================] - 11s 950ms/step - loss: 4.0477e-04 - accuracy: 1.0000 - val_loss: 3.8728 - val_accuracy: 0.4688
# Epoch 52/60
# 11/11 [==============================] - 11s 961ms/step - loss: 3.7744e-04 - accuracy: 1.0000 - val_loss: 2.7927 - val_accuracy: 0.5312
# Epoch 53/60
# 11/11 [==============================] - 10s 953ms/step - loss: 3.5930e-04 - accuracy: 1.0000 - val_loss: 3.5597 - val_accuracy: 0.4688
# Epoch 54/60
# 11/11 [==============================] - 10s 966ms/step - loss: 3.3960e-04 - accuracy: 1.0000 - val_loss: 4.2105 - val_accuracy: 0.3750
# Epoch 55/60
# 11/11 [==============================] - 10s 945ms/step - loss: 3.2803e-04 - accuracy: 1.0000 - val_loss: 3.7805 - val_accuracy: 0.4688
# Epoch 56/60
# 11/11 [==============================] - 11s 972ms/step - loss: 3.2076e-04 - accuracy: 1.0000 - val_loss: 4.3153 - val_accuracy: 0.3438
# Epoch 57/60
# 11/11 [==============================] - 11s 924ms/step - loss: 2.9004e-04 - accuracy: 1.0000 - val_loss: 3.3863 - val_accuracy: 0.5000
# Epoch 58/60
# 11/11 [==============================] - 11s 931ms/step - loss: 2.8525e-04 - accuracy: 1.0000 - val_loss: 3.1861 - val_accuracy: 0.4688
# Epoch 59/60
# 11/11 [==============================] - 10s 950ms/step - loss: 2.6886e-04 - accuracy: 1.0000 - val_loss: 4.2522 - val_accuracy: 0.4062
# Epoch 60/60
# 11/11 [==============================] - 11s 956ms/step - loss: 2.5954e-04 - accuracy: 1.0000 - val_loss: 3.0702 - val_accuracy: 0.5000
# 5/6 [========================>.....] - ETA: 0s - loss: 3.2723 - accuracy: 0.5750WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# 6/6 [==============================] - 5s 730ms/step - loss: 3.2723 - accuracy: 0.5750
# 5/6 [========================>.....] - ETA: 0sWARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6 batches). You may need to use the repeat() function when building your dataset.
# 6/6 [==============================] - 5s 800ms/step
#
# 訓練完成 - epochs: 60, batch_size: 16
# 訓練集準確率: 1.0000, 損失: 0.0003
# 驗證集準確率: 0.5000, 損失: 3.0702
# 測試集準確率: 0.5750, 損失: 3.2723
# 整體準確率(不分性別): 0.5750
# 訓練時間: 0:10:35
# 各類別準確率:
#   men: 0.5250
#   women: 0.6250

# %%
# 創建並展示結果摘要
print("\n實驗結果摘要:")
print("-" * 132)
print(f"{'參數組合':<20}{'訓練準確率':<12}{'驗證準確率':<12}{'測試準確率':<12}{'訓練損失':<12}{'驗證損失':<12}{'測試損失':<12}{'訓練時間':<12}{'整體準確率':<12}{'men準確率':<12}{'women準確率':<12}")
print("-" * 132)
# Out:
# 實驗結果摘要:
# ------------------------------------------------------------------------------------------------------------------------------------
# 參數組合                訓練準確率       驗證準確率       測試準確率       訓練損失        驗證損失        測試損失        訓練時間        整體準確率       men準確率      women準確率
# ------------------------------------------------------------------------------------------------------------------------------------

# %%
for key, data in results.items():
    print(f"{key:<20}{data['train_acc']:.4f}{'':<4}{data['val_acc']:.4f}{'':<4}{data['test_acc']:.4f}{'':<4}{data['train_loss']:.4f}{'':<4}{data['val_loss']:.4f}{'':<4}{data['test_loss']:.4f}{'':<4}{data['formatted_time']:<12}{data['overall_accuracy']:.4f}{'':<4}{data['class_accuracies'].get('men', 0.0):.4f}{'':<4}{data['class_accuracies'].get('women', 0.0):.4f}")

# 將結果也輸出為DataFrame格式
summary_data = []
for key, data in results.items():
    epochs, batch_size = key.split('_')[1], key.split('_')[3]
    summary_data.append({
        'Epochs': epochs,
        'Batch Size': batch_size,
        'Train Accuracy': f"{data['train_acc']:.4f}",
        'Val Accuracy': f"{data['val_acc']:.4f}" if data['val_acc'] is not None else "N/A",
        'Test Accuracy': f"{data['test_acc']:.4f}",
        'Train Loss': f"{data['train_loss']:.4f}",
        'Val Loss': f"{data['val_loss']:.4f}" if data['val_loss'] is not None else "N/A",
        'Test Loss': f"{data['test_loss']:.4f}",
        'Training Time': data['formatted_time'],
        'Overall Accuracy': f"{data['overall_accuracy']:.4f}",
        'Men Accuracy': f"{data['class_accuracies'].get('men', 0.0):.4f}",
        'Women Accuracy': f"{data['class_accuracies'].get('women', 0.0):.4f}"
    })

summary_df = pd.DataFrame(summary_data)
print("\n以DataFrame格式的摘要:")
print(summary_df)

# 保存摘要為CSV
summary_df.to_csv(summary_csv_filename, index=False)
# Out:
# epochs_20_batch_8   1.0000    0.4250    0.5000    0.0015    3.6506    2.1837    0:03:43     0.5000    0.4750    0.5250
# epochs_20_batch_16  1.0000    0.3750    0.5375    0.0057    3.0790    2.0338    0:03:39     0.5375    0.5500    0.5250
# epochs_40_batch_8   1.0000    0.5250    0.6000    0.0001    3.9149    2.7745    0:07:10     0.6000    0.5750    0.6250
# epochs_40_batch_16  1.0000    0.5000    0.5500    0.0004    3.5253    3.0345    0:07:15     0.5500    0.5500    0.5500
# epochs_60_batch_8   1.0000    0.5000    0.6125    0.0000    4.1798    2.9921    0:10:47     0.6125    0.6250    0.6000
# epochs_60_batch_16  1.0000    0.5000    0.5750    0.0003    3.0702    3.2723    0:10:35     0.5750    0.5250    0.6250
#
# 以DataFrame格式的摘要:
#   Epochs Batch Size Train Accuracy Val Accuracy Test Accuracy Train Loss  \
# 0     20          8         1.0000       0.4250        0.5000     0.0015
# 1     20         16         1.0000       0.3750        0.5375     0.0057
# 2     40          8         1.0000       0.5250        0.6000     0.0001
# 3     40         16         1.0000       0.5000        0.5500     0.0004
# 4     60          8         1.0000       0.5000        0.6125     0.0000
# 5     60         16         1.0000       0.5000        0.5750     0.0003
#
#   Val Loss Test Loss Training Time Overall Accuracy Men Accuracy  \
# 0   3.6506    2.1837       0:03:43           0.5000       0.4750
# 1   3.0790    2.0338       0:03:39           0.5375       0.5500
# 2   3.9149    2.7745       0:07:10           0.6000       0.5750
# 3   3.5253    3.0345       0:07:15           0.5500       0.5500
# 4   4.1798    2.9921       0:10:47           0.6125       0.6250
# 5   3.0702    3.2723       0:10:35           0.5750       0.5250
#
#   Women Accuracy
# 0         0.5250
# 1         0.5250
# 2         0.6250
# 3         0.5500
# 4         0.6000
# 5         0.6250

# %%
import matplotlib.pyplot as plt

for key, data in results.items():
    plt.figure(figsize=(15, 5))  # 調整圖的大小以適應單個組合

    # 繪製訓練和驗證準確率
    plt.subplot(1, 2, 1)  # 使用 1 行 2 列的子圖
    epochs_count = len(data['history']['accuracy'])
    epochs_range = range(1, epochs_count + 1)
    plt.plot(epochs_range, data['history']['accuracy'], '-', label=f"{key} (train)")
    if 'val_accuracy' in data['history']:
        plt.plot(epochs_range, data['history']['val_accuracy'], '--', label=f"{key} (val)")
    plt.title(f'{key} - Train and Val Acc')
    plt.xlabel('Epochs')
    plt.ylabel('Acc')
    plt.legend(loc='lower right')
    plt.grid(True)

    # 繪製訓練和驗證損失
    plt.subplot(1, 2, 2)
    epochs_count = len(data['history']['loss'])
    epochs_range = range(1, epochs_count + 1)
    plt.plot(epochs_range, data['history']['loss'], '-', label=f"{key} (train)")
    if 'val_loss' in data['history']:
        plt.plot(epochs_range, data['history']['val_loss'], '--', label=f"{key} (val)")
    plt.title(f'{key} - Train and Val Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.grid(True)

    plt.tight_layout()
    filename = f'original_training_{key.replace(" ", "_")}.png'  # 創建包含參數組合名稱的文件名
    filepath = os.path.join(output_dir, filename)  # 組合路徑和檔名
    plt.savefig(filepath)
    print(f"參數組合 '{key}' 的訓練過程圖表已保存至: {filepath}")


print(f"\n所有參數組合的結果也已保存至: {csv_filename}, {detailed_csv_filename}, {summary_csv_filename}")
# Out:
# 參數組合 'epochs_20_batch_8' 的訓練過程圖表已保存至: C:/Users/user/Desktop/MLWORK/original\original_training_epochs_20_batch_8.png
# 參數組合 'epochs_20_batch_16' 的訓練過程圖表已保存至: C:/Users/user/Desktop/MLWORK/original\original_training_epochs_20_batch_16.png
# 參數組合 'epochs_40_batch_8' 的訓練過程圖表已保存至: C:/Users/user/Desktop/MLWORK/original\original_training_epochs_40_batch_8.png
# 參數組合 'epochs_40_batch_16' 的訓練過程圖表已保存至: C:/Users/user/Desktop/MLWORK/original\original_training_epochs_40_batch_16.png
# 參數組合 'epochs_60_batch_8' 的訓練過程圖表已保存至: C:/Users/user/Desktop/MLWORK/original\original_training_epochs_60_batch_8.png
# 參數組合 'epochs_60_batch_16' 的訓練過程圖表已保存至: C:/Users/user/Desktop/MLWORK/original\original_training_epochs_60_batch_16.png
#
# 所有參數組合的結果也已保存至: original_training_results.csv, C:/Users/user/Desktop/MLWORK/original\original_detailed_training_results.csv, C:/Users/user/Desktop/MLWORK/original\original_summary_results.csv

# %%
# 建立比較表格，以DataFrame方式顯示不同組合間的性能
comparison_table = pd.DataFrame({
    'Epochs_Batch': [key for key in results.keys()],
    'Test Acc': [results[key]['test_acc'] for key in results.keys()],
    'Train Acc': [results[key]['train_acc'] for key in results.keys()],
    'Val Acc': [results[key]['val_acc'] for key in results.keys()],
    'Test Loss': [results[key]['test_loss'] for key in results.keys()],
    'Train Loss': [results[key]['train_loss'] for key in results.keys()],
    'Val Loss': [results[key]['val_loss'] for key in results.keys()],
    'Training Time': [results[key]['formatted_time'] for key in results.keys()],
    'Overall Acc': [results[key]['overall_accuracy'] for key in results.keys()],
    'Men Acc': [results[key]['class_accuracies'].get('men', 0.0) for key in results.keys()],
    'Women Acc': [results[key]['class_accuracies'].get('women', 0.0) for key in results.keys()],
})
print("\n參數組合比較表:")
print(comparison_table.sort_values(by='Test Acc', ascending=False))
# Out:
# 參數組合比較表:
#          Epochs_Batch  Test Acc  Train Acc  Val Acc  Test Loss  Train Loss  \
# 4   epochs_60_batch_8    0.6125        1.0    0.500   2.992092    0.000044
# 2   epochs_40_batch_8    0.6000        1.0    0.525   2.774516    0.000110
# 5  epochs_60_batch_16    0.5750        1.0    0.500   3.272279    0.000260
# 3  epochs_40_batch_16    0.5500        1.0    0.500   3.034517    0.000424
# 1  epochs_20_batch_16    0.5375        1.0    0.375   2.033837    0.005734
# 0   epochs_20_batch_8    0.5000        1.0    0.425   2.183687    0.001502
#
#    Val Loss Training Time  Overall Acc  Men Acc  Women Acc
# 4  4.179776       0:10:47       0.6125    0.625      0.600
# 2  3.914920       0:07:10       0.6000    0.575      0.625
# 5  3.070210       0:10:35       0.5750    0.525      0.625
# 3  3.525349       0:07:15       0.5500    0.550      0.550
# 1  3.079024       0:03:39       0.5375    0.550      0.525
# 0  3.650631       0:03:43       0.5000    0.475      0.525
